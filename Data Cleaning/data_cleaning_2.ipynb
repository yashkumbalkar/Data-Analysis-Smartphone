# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/smartphone_cleaned_my.csv')

# %%
df.shape
# Out:
# (877, 24)

# %%
df.head()
# Out:
#   brand_name                                    model  price  rating  has_5g  \
# 0    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0    True
# 1    samsung                    Samsung Galaxy A14 5G  16499    75.0    True
# 2    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0    True
# 3   motorola                     Motorola Moto G62 5G  14999    81.0    True
# 4     realme                       Realme 10 Pro Plus  24999    82.0    True
#
#    has_nfc  has_ir_blaster    processor_name processor_brand  num_cores  ...  \
# 0    False           False    Snapdragon 695      snapdragon  Octa Core  ...
# 1    False           False       Exynos 1330          exynos  Octa Core  ...
# 2     True           False  Snapdragon  750G      snapdragon  Octa Core  ...
# 3    False           False   Snapdragon  695      snapdragon  Octa Core  ...
# 4    False           False    Dimensity 1080       dimensity  Octa Core  ...
#
#    fast_charging  screen_size    resolution  refresh_rate  num_rear_cameras  \
# 0             33         6.59  1080 x 2412            120                 3
# 1             15         6.60  1080 x 2408             90                 3
# 2             25         6.60  1080 x 2408            120                 3
# 3              0         6.55  1080 x 2400            120                 3
# 4             67         6.70  1080 x 2412            120                 3
#
#    num_front_cameras       os  primary_camera_rear  primary_camera_front  \
# 0                  1  android                 64.0                  16.0
# 1                  1  android                 50.0                  13.0
# 2                  1  android                 50.0                   8.0
# 3                  1  android                 50.0                  16.0
# 4                  1  android                108.0                  16.0
#
#   extended_memory
# 0            1 TB
# 1            1 TB
# 2            1 TB
# 3            1 TB
# 4               0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            877 non-null    object
#  1   model                 877 non-null    object
#  2   price                 877 non-null    int64
#  3   rating                792 non-null    float64
#  4   has_5g                877 non-null    bool
#  5   has_nfc               877 non-null    bool
#  6   has_ir_blaster        877 non-null    bool
#  7   processor_name        848 non-null    object
#  8   processor_brand       848 non-null    object
#  9   num_cores             875 non-null    object
#  10  processor_speed       862 non-null    float64
#  11  ram_capacity          877 non-null    float64
#  12  internal_memory       877 non-null    float64
#  13  battery_capacity      865 non-null    float64
#  14  fast_charging         877 non-null    int64
#  15  screen_size           877 non-null    float64
#  16  resolution            877 non-null    object
#  17  refresh_rate          877 non-null    int64
#  18  num_rear_cameras      877 non-null    int64
#  19  num_front_cameras     877 non-null    object
#  20  os                    877 non-null    object
#  21  primary_camera_rear   877 non-null    float64
#  22  primary_camera_front  874 non-null    float64
#  23  extended_memory       877 non-null    object
# dtypes: bool(3), float64(8), int64(4), object(9)
# memory usage: 146.6+ KB

# %%
df.isnull().sum()
# Out:
# brand_name               0
# model                    0
# price                    0
# rating                  85
# has_5g                   0
# has_nfc                  0
# has_ir_blaster           0
# processor_name          29
# processor_brand         29
# num_cores                2
# processor_speed         15
# ram_capacity             0
# internal_memory          0
# battery_capacity        12
# fast_charging            0
# screen_size              0
# resolution               0
# refresh_rate             0
# num_rear_cameras         0
# num_front_cameras        0
# os                       0
# primary_camera_rear      0
# primary_camera_front     3
# extended_memory          0
# dtype: int64

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    313
# helio         254
# dimensity     107
# exynos         48
# bionic         40
# unisoc         32
# tiger          19
# qualcomm        9
# a13             7
# google          6
# spreadtrum      4
# sc9863a         3
# kirin           3
# fusion          1
# sprd            1
# mediatek        1
# Name: count, dtype: int64

# %%
temp_df = df[df['processor_brand'] == 'qualcomm']
df.loc[temp_df.index, 'processor_brand'] = 'snapdragon'

# %%
temp_df = df[df['processor_brand'] == 'a13']
df.loc[temp_df.index, 'processor_brand'] = 'bionic'

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    322
# helio         254
# dimensity     107
# exynos         48
# bionic         47
# unisoc         32
# tiger          19
# google          6
# spreadtrum      4
# sc9863a         3
# kirin           3
# fusion          1
# sprd            1
# mediatek        1
# Name: count, dtype: int64

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    769
# Quad Core     58
# Hexa Core     47
# Deca Core      1
# Name: count, dtype: int64

# %%
def fast(row):

  if row['fast_charging'] == -1:
    return 0
  else:
    return 1

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'num_cores',
#        'processor_speed', 'ram_capacity', 'internal_memory',
#        'battery_capacity', 'fast_charging', 'screen_size', 'resolution',
#        'refresh_rate', 'num_rear_cameras', 'num_front_cameras', 'os',
#        'primary_camera_rear', 'primary_camera_front', 'extended_memory'],
#       dtype='object')

# %%
x = df.apply(fast,axis=1)
df.insert(14,'fast_charging_available',x)

# %%
df['fast_charging_available'].value_counts()
# Out:
# fast_charging_available
# 1    638
# 0    239
# Name: count, dtype: int64

# %%
df['fast_charging'] = df['fast_charging'].apply(lambda x:np.nan if x == 0 or x == -1 else x)

# %%
df['extended_memory'].value_counts()
# Out:
# extended_memory
# 1 TB                    215
# 0                       213
# 256 GB                  178
# 512 GB                  139
# Not Specified            55
# 128 GB                   32
# Memory Card (Hybrid)     22
# 64 GB                    10
# 2 TB                      9
# 32 GB                     3
# 400 GB                    1
# Name: count, dtype: int64

# %%
df['extended_memory_available'] = df['extended_memory'].apply(lambda x:0 if x == '0' else 1)

# %%
df['extended_memory_available'].value_counts()
# Out:
# extended_memory_available
# 1    664
# 0    213
# Name: count, dtype: int64

# %%
def extended_extractor(row):
  if row['extended_memory'] == '0':
    return np.nan
  elif row['extended_memory'] == 'Not Specified':
    return np.nan
  elif row['extended_memory'] == 'Memory Card (Hybrid)':
    return np.nan
  else:
    return row['extended_memory']

# %%
x = df.apply(extended_extractor,axis=1).str.replace('\u2009',' ').str.split(' ').str.get(0)
df['extended_upto'] = x
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1      215
# 256    178
# 512    139
# 128     32
# 64      10
# 2        9
# 32       3
# 400      1
# Name: count, dtype: int64

# %%
def transform(text):

  if text == '1':
    return '1024'
  elif text == '2':
    return '2048'
  elif text == '400':
    return '512'
  else:
    return text

# %%
df['extended_upto'] = df['extended_upto'].apply(transform)

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1024    215
# 256     178
# 512     140
# 128      32
# 64       10
# 2048      9
# 32        3
# Name: count, dtype: int64

# %%
df['os'].value_counts()
# Out:
# os
# android          822
# ios               48
# Not Specified      5
# other              2
# Name: count, dtype: int64

# %%
def os_transform(text):

  if 'Not Specified' in text:
    return np.nan
  elif 'android' in text:
    return text
  elif 'ios' in text:
    return text
  else:
    return 'other'

# %%
df['os'] = df['os'].apply(os_transform)

# %%
df['os'].value_counts()
# Out:
# os
# android    822
# ios         48
# other        2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   brand_name                                    model  price  rating  has_5g  \
# 0    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0    True
# 1    samsung                    Samsung Galaxy A14 5G  16499    75.0    True
# 2    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0    True
# 3   motorola                     Motorola Moto G62 5G  14999    81.0    True
# 4     realme                       Realme 10 Pro Plus  24999    82.0    True
#
#    has_nfc  has_ir_blaster    processor_name processor_brand  num_cores  ...  \
# 0    False           False    Snapdragon 695      snapdragon  Octa Core  ...
# 1    False           False       Exynos 1330          exynos  Octa Core  ...
# 2     True           False  Snapdragon  750G      snapdragon  Octa Core  ...
# 3    False           False   Snapdragon  695      snapdragon  Octa Core  ...
# 4    False           False    Dimensity 1080       dimensity  Octa Core  ...
#
#      resolution  refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0  1080 x 2412            120                 3                  1  android
# 1  1080 x 2408             90                 3                  1  android
# 2  1080 x 2408            120                 3                  1  android
# 3  1080 x 2400            120                 3                  1  android
# 4  1080 x 2412            120                 3                  1  android
#
#    primary_camera_rear  primary_camera_front extended_memory  \
# 0                 64.0                  16.0            1 TB
# 1                 50.0                  13.0            1 TB
# 2                 50.0                   8.0            1 TB
# 3                 50.0                  16.0            1 TB
# 4                108.0                  16.0               0
#
#    extended_memory_available  extended_upto
# 0                          1           1024
# 1                          1           1024
# 2                          1           1024
# 3                          1           1024
# 4                          0            NaN
#
# [5 rows x 27 columns]

# %%
df.drop(columns=['processor_name','extended_memory'],inplace=True)

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    769
# Quad Core     58
# Hexa Core     47
# Deca Core      1
# Name: count, dtype: int64

# %%
df['num_cores'] = df['num_cores'].str.replace('Octa Core','8')
df['num_cores'] = df['num_cores'].str.replace('Hexa Core','6')
df['num_cores'] = df['num_cores'].str.replace('Quad Core','4')
df['num_cores'] = df['num_cores'].str.replace('Deca Core','8')

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# 8    770
# 4     58
# 6     47
# Name: count, dtype: int64

# %%
df['num_cores'] = df['num_cores'].astype(float)

# %%
temp_df = df[df['num_front_cameras'] == 'Missing']
df.loc[temp_df.index,'num_front_cameras'] = np.nan

# %%
df['num_front_cameras'] = df['num_front_cameras'].astype(float)

# %%
df.to_csv('smartphone_cleaned_my3.csv',index=False)
