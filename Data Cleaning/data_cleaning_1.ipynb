# %% [markdown]
# #### **About DataSet** **:-** This dataset contains detailed information about various smartphones scraped from the Smartprix website. It includes key attributes such as model name, price, processor type, RAM capacity, storage options, camera specifications, battery life, and additional features. This dataset is ideal for predicting the price of smartphones based on various Features.
#
# #### **Attribute Information**
#
# * `model` : Model Name of each Phone.
# * `price` : Price of each phone.
# * `rating` : Rating of each phone.
# * `sim` : Features of phone like dual sim,3G,4G,5G,NFC etc.
# * `processor_` : Name of processor,number of cores,speed of processor used in each phone.
# * `ram` : Ram and internal memory of each phone.
# * `battery` : Battery power of each phone in "mAh" and availablitiy of Fast charging.
# * `display` : Screen size, Resolution and Refresh rate of each phone.
# * `camera` : camera detail of Rear and Front camera.
# * `card` : Availablity of memory card and its capacity.
# * `os` : Operating System of each phone.

# %%
import numpy as np
import pandas as pd

# %%
# Show all columns and rows
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('smartphones.csv')

# %%
df.head()
# Out:
#                                      model    price  rating  \
# 0                OnePlus Nord CE 2 Lite 5G  ₹18,999    81.0
# 1                    Samsung Galaxy A14 5G  ₹16,499    75.0
# 2  Samsung Galaxy F23 5G (6GB RAM + 128GB)  ₹16,999    80.0
# 3                     Motorola Moto G62 5G  ₹14,999    81.0
# 4                       Realme 10 Pro Plus  ₹24,999    82.0
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# ## Data Assessing
#
# ### Quality Issues
#
# 1. **model** - some brands are written diiferently like OPPO in model column `consistency`
# 2. **price** - has unneccesary '₹' `validity`
# 3. **price** - has ',' between numbers `validity`
# 4. **price** - phone Namotel has a price of 99 and some phones have prices under 1000 rupees `accuracy`
# 5. **ratings** - missing values `completeness`
# 6. **processor** - has some incorrect values for some phones (row # -272,290,336,351,372,374,404,430,445,477,480,495,496,526,557,566,591,612,619,699,700,710,712,713,737,741,748,750,770,772,776,778,780,782,785,789,792,796,797,802,813,837,859,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,900,901,913,934,954,958,966,973,974,981,995,996,1001,1002,1004,1005,1006,1021) `validity`
# 7. There is ipod on row 756 `validity`
# 8. **ram** - incorrect values in rows (268,272,290,315,374,404,430,445,477,480,496,526,535,552,557,566,591,612,619,643,655,699,700,710,713,734,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,859,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,934,958,966,973,974,981,995,996,1001,1004,1005,1006,1009,1021) `validity`
# 9. **battery** - incorrect values in rows (246,268,272,290,362,374,404,430,445,477,480,496,508,526,535,548,552,557,566,588,612,619,643,655,699,700,710,713,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,861,863,864,865,867,868,869,870,871,874,875,888,897,899,901,931,934,954,958,966,973,974,996,1001,1004,1005,1006,1009,1021) `validity`
# 10. **display** - sometimes frequency is not available `completeness`
# 11. **display** - incorrect values in rows(87,119,221,268,272,290,362,374,404,445,477,480,496,508,526,535,548,552,557,566,588,612,619,643,655,699,700,710,713,724,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,931,934,954,958,966,973,974,996,1001,1004,1005,1006,1009,1021) `validity`
# 12. **camera** - words like Dual, Triple and Quad are used to represent number of cameras and front and rear cameras are separated by '&'
# 13. **camera** - problem with rows (87,119,126,221,244,246,268,272,290,328,349,351,362,372,374,404,430,440,445,477,480,495,496,508,526,529,535,548,552,557,566,588,609,612,619,643,655,665,699,700,705,710,713,724,737,741,748,750,776,777,778,780,782,785,789,792,794,796,797,802,837,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,931,954,958,973,974,996,1001,1004,1005,1006,1009,1021)  `validity`
# 14. **card** - sometimes contains info about os and camera `validity`
# 15. **os** - sometimes contains info about bluetooth and fm radio `validity`
# 16. **os** - issue with rows (324,378) `validity`
# 17. **os** - sometimes contains os version name like lollipop `consistency`
# 18. missing values in camera, card and os `completeness`
# 19. datatype  of price and rating is incorrect `validity`
#
#
#
# ### Tidiness Issues
#
# 1. **sim** - can be split into 3 cols has_5g, has_NFC, has_IR_Blaster
# 2. **ram** - can be split into 2 cols RAM and ROM
# 3. **processor** - can be split into processor name, cores and cpu speed.
# 4. **battery** - can be split into battery capacity, fast_charging_available
# 5. **display** - can be split into size, resolution_width, resolution_height and frequency
# 6. **camera** - can be split into front and rear camera
# 7. **card** - can be split into supported, extended_upto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   model      1020 non-null   object
#  1   price      1020 non-null   object
#  2   rating     793 non-null    float64
#  3   sim        1020 non-null   object
#  4   processor  1020 non-null   object
#  5   ram        1020 non-null   object
#  6   battery    1020 non-null   object
#  7   display    1020 non-null   object
#  8   camera     1018 non-null   object
#  9   card       993 non-null    object
#  10  os         951 non-null    object
# dtypes: float64(1), object(10)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#            rating
# count  793.000000
# mean    75.833544
# std      8.082594
# min     60.000000
# 25%     69.000000
# 50%     77.000000
# 75%     82.000000
# max     89.000000

# %%
# check for duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# make a copy
df1 = df.copy()

# %%
# cleaning Price column into integer data type
df1['price'] = df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df1.head()
# Out:
#                                      model  price  rating  \
# 0                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1                    Samsung Galaxy A14 5G  16499    75.0
# 2  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3                     Motorola Moto G62 5G  14999    81.0
# 4                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1 = df1.reset_index()

# %%
df1['index'] = df1['index'] + 2

# %%
df1.head()
# Out:
#    index                                    model  price  rating  \
# 0      2                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3                    Samsung Galaxy A14 5G  16499    75.0
# 2      4  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5                     Motorola Moto G62 5G  14999    81.0
# 4      6                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **All the number of rows having Data Quality issues**

# %%
processor_rows = set((272,290,336,351,372,374,404,430,445,477,480,495,496,526,557,566,591,612,619,699,700,710,712,713,737,741,748,750,770,772,776,778,780,782,785,789,792,796,797,802,813,837,859,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,900,901,913,934,954,958,966,973,974,981,995,996,1001,1002,1004,1005,1006,1021))
ram_rows = set((268,272,290,315,374,404,430,445,477,480,496,526,535,552,557,566,591,612,619,643,655,699,700,710,713,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,859,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,934,958,966,973,974,981,995,996,1001,1004,1005,1006,1009,1021))
battery_rows = set((246,268,272,290,362,374,404,430,445,477,480,496,508,526,535,548,552,557,566,588,612,619,643,655,699,700,710,713,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,861,863,864,865,867,868,869,870,871,874,875,888,897,899,901,931,934,954,958,966,973,974,996,1001,1004,1005,1006,1009,1021))
display_rows = set((87,119,221,268,272,290,362,374,404,445,477,480,496,508,526,535,548,552,557,566,588,612,619,643,655,699,700,710,713,724,737,748,750,776,777,778,780,782,785,789,792,796,797,802,813,837,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,931,934,954,958,966,973,974,996,1001,1004,1005,1006,1009,1021))
camera_rows = set((87,119,126,221,244,246,268,272,290,328,349,351,362,372,374,404,430,440,445,477,480,495,496,508,526,529,535,548,552,557,566,588,609,612,619,643,655,665,699,700,705,710,713,724,737,741,748,750,776,777,778,780,782,785,789,792,794,796,797,802,837,861,863,864,865,867,868,869,870,871,874,875,879,888,897,899,901,931,954,958,973,974,996,1001,1004,1005,1006,1009,1021))

# %%
df1[df1['index'].isin(processor_rows | ram_rows | battery_rows | display_rows | camera_rows)]
# Out:
#       index                                          model   price  rating  \
# 85       87                                Apple iPhone 12   53900    74.0
# 117     119                           Apple iPhone 12 Mini   40999    74.0
# 124     126                        Samsung Galaxy Z Flip 3   69999    84.0
# 219     221                        Apple iPhone 12 (128GB)   57900    75.0
# 242     244                        Samsung Galaxy Z Fold 4  146999     NaN
# 244     246                   Apple iPhone 12 Mini (128GB)   45999    75.0
# 266     268                         Apple iPhone SE 3 2022   43900     NaN
# 270     272                          Samsung Guru GT-E1215    1599     NaN
# 288     290                                Nokia 2660 Flip    4649     NaN
# 313     315               Huawei Mate 50 RS Porsche Design  239999    81.0
# 326     328                     Samsung Galaxy Z Flip 4 5G   82999    88.0
# 334     336                                   Nokia 110 4G    1762     NaN
# 347     349                                     LG Wing 5G   54999    89.0
# 349     351                               Nokia 105 (2019)    1299     NaN
# 360     362                    Apple iPhone 12 Pro (512GB)  139900    80.0
# 370     372                  Samsung Guru Music 2 Dual Sim    1949     NaN
# 372     374                                  Nokia 8210 4G    3749     NaN
# 402     404                                itel Magic 2 4G    2399     NaN
# 428     430                                 Nokia 105 Plus    1299     NaN
# 438     440                        Samsung Galaxy Z Fold 3  110999    89.0
# 443     445                                   itel it2163S     958     NaN
# 475     477                                   itel Magic X    2239     NaN
# 478     480                              Motorola Moto A10    1339     NaN
# 493     495                               Nokia 110 (2022)    1599     NaN
# 494     496                         Nokia 5710 XpressAudio    4799     NaN
# 506     508                        Apple iPhone 12 (256GB)   67999    76.0
# 524     526                              GreenBerry Rafale     899     NaN
# 527     529       Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 533     535                 Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546     548                   Apple iPhone 12 Mini (256GB)   55999    75.0
# 550     552                            Nokia 5310 Dual Sim    3399     NaN
# 555     557                             Samsung Guru E1200    1685     NaN
# 564     566                               Kechaoda K55 Pro    1180     NaN
# 586     588                    Apple iPhone 12 Pro (256GB)  119900    80.0
# 589     591                               Nokia 150 (2020)    2499     NaN
# 607     609     Samsung Galaxy Z Fold 4 (12GB RAM + 512GB)  156999     NaN
# 610     612                             Micromax X513 Plus     949     NaN
# 617     619                                 Itel Power 700    1899     NaN
# 641     643                               iKall K88 Pro 4G    2099     NaN
# 653     655                 Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 663     665   Samsung Galaxy Z Flip 3 5G (8GB RAM + 256GB)   83999    85.0
# 697     699                                XTouch F40 Flip    1999     NaN
# 698     700                                 Lava Gem Power    1977     NaN
# 703     705      Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   94999    88.0
# 708     710                              Motorola Moto A70    1960     NaN
# 710     712                                  Lava A3 Power    1299     NaN
# 711     713                                   itel Magic 3    1498     NaN
# 722     724                                      Lava Flip    1779     NaN
# 735     737                                      Nokia 125    2099     NaN
# 739     741                               Nokia 110 (2019)    1599     NaN
# 746     748                                       Lava Gem    1499     NaN
# 748     750                                  Kechaoda K112    1618     NaN
# 768     770                                 Lava Hero 600i     849     NaN
# 770     772                                   itel MX Play    2147     NaN
# 774     776                      Nokia 105 Plus Single Sim    1399     NaN
# 775     777                                    itel it2175    1005     NaN
# 776     778                        Nokia 105 Dual Sim 2022    1449     NaN
# 778     780                                 Nokia 105 2022    1299     NaN
# 780     782                                   Lava A7 Star    1529     NaN
# 783     785                                       Lava Z21    5299     NaN
# 787     789                              Motorola Moto A50    1584     NaN
# 790     792                            Philips Xenium E125    1349     NaN
# 792     794  Samsung Galaxy Z Fold 3 5G (12GB RAM + 512GB)  101800    89.0
# 794     796                                iKall K24 Ultra    1049     NaN
# 795     797                 Kechaoda K66 The Music House 4    1160     NaN
# 800     802                                 Karbonn K9 Max    1429     NaN
# 811     813                                  Lava 34 Ultra    1599     NaN
# 835     837                                      Realme 6i   12390    75.0
# 857     859                                      Nokia 105    1390     NaN
# 859     861                                 itel Power 200    1379     NaN
# 861     863                                   Mafe X1 Plus     999     NaN
# 862     864                                   BlackZone C9     899     NaN
# 863     865                                   BlackZone C6    1049     NaN
# 865     867                             Itel Power 110 Neo    1325     NaN
# 866     868                                  Micromax S114    1128     NaN
# 867     869                             Kechaoda K102 Plus    1299     NaN
# 868     870                                Itel Power 110N    1325     NaN
# 869     871                                    Lava LF9000    1880     NaN
# 872     874                                 Itel Power 430    1499     NaN
# 873     875                                itel Ace 2 Star     899     NaN
# 877     879                                    Itel Ace 2N     889     NaN
# 886     888                                        Vox V14     883     NaN
# 895     897                                    Kechaoda A6    1449     NaN
# 897     899                              Lava A1 Josh 2021    1139     NaN
# 898     900                                Easyfone Shield    2480     NaN
# 899     901                                   Lava A1 2021    1079     NaN
# 911     913                                    itel it5626    1738     NaN
# 929     931                Apple iPhone 12 Pro Max (512GB)  149900    81.0
# 932     934                             Lava Hero 600 Plus     900     NaN
# 952     954                                        Lava A5    1379     NaN
# 956     958                      Nokia 105 Dual SIM (2019)    1299     NaN
# 964     966                                   Kechaoda A27    1099     NaN
# 971     973                                Easyfone Royale    3499     NaN
# 972     974                                   Kechaoda K10    1160     NaN
# 979     981                              Nokia 3310 (2017)    3699     NaN
# 993     995                      Samsung Star 3 Duos S5222    8990     NaN
# 994     996                             Telefono S1 Dazzle     899     NaN
# 999    1001                               Snexian Bold 12K    1499     NaN
# 1000   1002                               Telefono T1 Josh     999     NaN
# 1002   1004                               Telefono T1 Star     949     NaN
# 1003   1005                                  iKall K15 New     849     NaN
# 1004   1006                                  iKall K52 New     839     NaN
# 1007   1009                                 MTR M2100 Plus     890     NaN
# 1019   1021                                         MTR M7    1050     NaN
#
#                                                   sim  \
# 85            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 117           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 124         Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 242           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 244           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 270                                        Single Sim
# 288                                  Dual Sim, 3G, 4G
# 313   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 326           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 334                           Dual Sim, 3G, 4G, VoLTE
# 347           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 349                                        Single Sim
# 360           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 370                                          Dual Sim
# 372                                  Dual Sim, 3G, 4G
# 402                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 428                                          Dual Sim
# 438           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 443                                          Dual Sim
# 475                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 478                                          Dual Sim
# 493                                          Dual Sim
# 494                                  Dual Sim, 3G, 4G
# 506           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 524                                          Dual Sim
# 527           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 550                                          Dual Sim
# 555                                        Single Sim
# 564                                          Dual Sim
# 586           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 589                                          Dual Sim
# 607           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 610                                          Dual Sim
# 617                                        Triple Sim
# 641                           Dual Sim, 3G, 4G, VoLTE
# 653           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 663         Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 697                                          Dual Sim
# 698                                          Dual Sim
# 703           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 708                                          Dual Sim
# 710                                          Dual Sim
# 711                                          Dual Sim
# 722                                          Dual Sim
# 735                                          Dual Sim
# 739                                          Dual Sim
# 746                                          Dual Sim
# 748                                        Triple Sim
# 768                                          Dual Sim
# 770                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 774                                        Single Sim
# 775                                          Dual Sim
# 776                                          Dual Sim
# 778                                        Single Sim
# 780                                          Dual Sim
# 783                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 787                                          Dual Sim
# 790                               Dual Sim, 3G, Wi-Fi
# 792           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 794                                          Dual Sim
# 795                                          Dual Sim
# 800                                          Dual Sim
# 811                                          Dual Sim
# 835                    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 857                                        Single Sim
# 859                                          Dual Sim
# 861                                          Dual Sim
# 862                                          Dual Sim
# 863                                          Dual Sim
# 865                                          Dual Sim
# 866                                          Dual Sim
# 867                                          Dual Sim
# 868                                          Dual Sim
# 869                                          Dual Sim
# 872                                          Dual Sim
# 873                                          Dual Sim
# 877                                          Dual Sim
# 886                                          Dual Sim
# 895                                        Triple Sim
# 897                                          Dual Sim
# 898                                          Dual Sim
# 899                                          Dual Sim
# 911                                        Triple Sim
# 929           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 932                                          Dual Sim
# 952                                          Dual Sim
# 956                                          Dual Sim
# 964                                          Dual Sim
# 971                                        Single Sim
# 972                                        Single Sim
# 979                                          Dual Sim
# 993                                   Dual Sim, Wi-Fi
# 994                                          Dual Sim
# 999                                          Dual Sim
# 1000                                         Dual Sim
# 1002                                         Dual Sim
# 1003                                         Dual Sim
# 1004                                         Dual Sim
# 1007                                         Dual Sim
# 1019                                         Dual Sim
#
#                                               processor  \
# 85             Bionic A14, Hexa Core, 3.1 GHz Processor
# 117            Bionic A14, Hexa Core, 3.1 GHz Processor
# 124       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 219            Bionic A14, Hexa Core, 3.1 GHz Processor
# 242   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 244            Bionic A14, Hexa Core, 3.1 GHz Processor
# 266          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 270                                     800 mAh Battery
# 288                                             No Wifi
# 313    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 326   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 334                                             No Wifi
# 347     Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 349                                             No Wifi
# 360            Bionic A14, Hexa Core, 3.1 GHz Processor
# 370                                             No Wifi
# 372                                             No Wifi
# 402                                               No 3G
# 428                              4 MB RAM, 4 MB inbuilt
# 438       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 443                              4 MB RAM, 4 MB inbuilt
# 475                                               No 3G
# 478                              4 MB RAM, 4 MB inbuilt
# 493                                             No Wifi
# 494                                             No Wifi
# 506            Bionic A14, Hexa Core, 3.1 GHz Processor
# 524                                               No 3G
# 527   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 533          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 546            Bionic A14, Hexa Core, 3.1 GHz Processor
# 550                             8 MB RAM, 16 MB inbuilt
# 555                                             No Wifi
# 564                            32 MB RAM, 64 MB inbuilt
# 586            Bionic A14, Hexa Core, 3.1 GHz Processor
# 589                                             No Wifi
# 607   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 610                            32 MB RAM, 32 MB inbuilt
# 617                                    2500 mAh Battery
# 641                           48 MB RAM, 128 MB inbuilt
# 653          Bionic  A15, Hexa Core, 3.22 GHz Processor
# 663       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 697                                               No 3G
# 698                                               No 3G
# 703   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 708                              4 MB RAM, 4 MB inbuilt
# 710                                             No Wifi
# 711                              8 MB RAM, 8 MB inbuilt
# 722                                             No Wifi
# 735                                             No Wifi
# 739                                             No Wifi
# 746                                               No 3G
# 748                                               No 3G
# 768                                               No 3G
# 770                                               No 3G
# 774                              4 MB RAM, 4 MB inbuilt
# 775                                   260 MHz Processor
# 776                              4 MB RAM, 4 MB inbuilt
# 778                              4 MB RAM, 4 MB inbuilt
# 780                            24 MB RAM, 32 MB inbuilt
# 783                             2 GB RAM, 32 GB inbuilt
# 787                              4 MB RAM, 4 MB inbuilt
# 790                                    2000 mAh Battery
# 792       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 794                            32 MB RAM, 32 MB inbuilt
# 795                            32 MB RAM, 64 MB inbuilt
# 800                                               No 3G
# 811                            24 MB RAM, 32 MB inbuilt
# 835                                             No Wifi
# 857                                             No Wifi
# 859                            32 MB RAM, 32 MB inbuilt
# 861                                    1050 mAh Battery
# 862                            32 MB RAM, 32 MB inbuilt
# 863                            64 MB RAM, 64 MB inbuilt
# 865                                    2500 mAh Battery
# 866                                               No 3G
# 867                            32 MB RAM, 64 MB inbuilt
# 868                                    2500 mAh Battery
# 869                                               No 3G
# 872                              8 MB RAM, 8 MB inbuilt
# 873                                               No 3G
# 877                              4 MB RAM, 4 MB inbuilt
# 886                            32 MB RAM, 32 MB inbuilt
# 895                                        4 MB inbuilt
# 897                            32 MB RAM, 24 MB inbuilt
# 898                                             No Wifi
# 899                            32 MB RAM, 24 MB inbuilt
# 911                                             No Wifi
# 929            Bionic A14, Hexa Core, 3.1 GHz Processor
# 932                              4 MB RAM, 3 MB inbuilt
# 952                                    1000 mAh Battery
# 956                              4 MB RAM, 4 MB inbuilt
# 964                                               No 3G
# 971                                               No 3G
# 972                                               No 3G
# 979                                             No Wifi
# 993                                               No 3G
# 994                                               No 3G
# 999                                             No Wifi
# 1000                                            No Wifi
# 1002                                              No 3G
# 1003                           32 MB RAM, 64 MB inbuilt
# 1004                           32 MB RAM, 64 MB inbuilt
# 1007                           32 MB RAM, 32 MB inbuilt
# 1019                           32 MB RAM, 32 MB inbuilt
#
#                                             ram  \
# 85                      4 GB RAM, 64 GB inbuilt
# 117                     4 GB RAM, 64 GB inbuilt
# 124                    8 GB RAM, 128 GB inbuilt
# 219                    4 GB RAM, 128 GB inbuilt
# 242                   12 GB RAM, 256 GB inbuilt
# 244                    4 GB RAM, 128 GB inbuilt
# 266                               64 GB inbuilt
# 270            1.5 inches, 120 x 120 px Display
# 288                                 Unisoc T107
# 313                              512 GB inbuilt
# 326                    8 GB RAM, 128 GB inbuilt
# 334                   128 MB RAM, 48 MB inbuilt
# 347                    8 GB RAM, 128 GB inbuilt
# 349                      4 MB RAM, 4 MB inbuilt
# 360                    6 GB RAM, 512 GB inbuilt
# 370              Single Core, 208 MHz Processor
# 372                                 Unisoc T107
# 402                                        T117
# 428                             800 mAh Battery
# 438                   12 GB RAM, 256 GB inbuilt
# 443                            1200 mAh Battery
# 475                                        T117
# 478                            1750 mAh Battery
# 493                      4 MB RAM, 4 MB inbuilt
# 494                                 Unisoc T107
# 506                    4 GB RAM, 256 GB inbuilt
# 524                           1.2 MHz Processor
# 527                     12 GB RAM, 1 TB inbuilt
# 533                              128 GB inbuilt
# 546                    4 GB RAM, 256 GB inbuilt
# 550                            1200 mAh Battery
# 555                             800 mAh Battery
# 564                             400 mAh Battery
# 586                    6 GB RAM, 256 GB inbuilt
# 589                                4 MB inbuilt
# 607                   12 GB RAM, 512 GB inbuilt
# 610                            1750 mAh Battery
# 617            2.8 inches, 320 x 240 px Display
# 641                            1800 mAh Battery
# 653                              256 GB inbuilt
# 663                    8 GB RAM, 256 GB inbuilt
# 697                                     No Wifi
# 698                                     No Wifi
# 703                    8 GB RAM, 256 GB inbuilt
# 708                            1750 mAh Battery
# 710                    32 MB RAM, 24 MB inbuilt
# 711                            1500 mAh Battery
# 722                 MTK6261D, 260 MHz Processor
# 735                                       Helio
# 739                      4 MB RAM, 4 MB inbuilt
# 746                                     No Wifi
# 748                                     No Wifi
# 768                      4 MB RAM, 3 MB inbuilt
# 770                   48 MB RAM, 128 MB inbuilt
# 774                             800 mAh Battery
# 775                            1200 mAh Battery
# 776                             800 mAh Battery
# 778                             800 mAh Battery
# 780                            1800 mAh Battery
# 783                            3100 mAh Battery
# 787                            1750 mAh Battery
# 790           1.77 inches, 128 x 160 px Display
# 792                   12 GB RAM, 512 GB inbuilt
# 794                            2500 mAh Battery
# 795                             400 mAh Battery
# 800                                     No Wifi
# 811                            2575 mAh Battery
# 835   Helio G90T, Octa Core, 2.05 GHz Processor
# 857                                8 MB inbuilt
# 859                            2500 mAh Battery
# 861            1.8 inches, 128 x 160 px Display
# 862                            1100 mAh Battery
# 863                            2500 mAh Battery
# 865            1.8 inches, 128 x 160 px Display
# 866                                     No Wifi
# 867                            2500 mAh Battery
# 868            1.8 inches, 128 x 160 px Display
# 869                                     No Wifi
# 872                            2500 mAh Battery
# 873                                     No Wifi
# 877                            1000 mAh Battery
# 886                            2500 mAh Battery
# 895                            2500 mAh Battery
# 897                             800 mAh Battery
# 898                    32 MB RAM, 32 MB inbuilt
# 899                             800 mAh Battery
# 911                      8 MB RAM, 8 MB inbuilt
# 929                    6 GB RAM, 512 GB inbuilt
# 932                             620 mAh Battery
# 952            2.4 inches, 240 x 320 px Display
# 956                             800 mAh Battery
# 964                                     No Wifi
# 971                                     No Wifi
# 972                                     No Wifi
# 979                               16 MB inbuilt
# 993                               20 MB inbuilt
# 994                                     No Wifi
# 999                             1 MHz Processor
# 1000                    8 MB RAM, 16 MB inbuilt
# 1002                                    No Wifi
# 1003                           1000 mAh Battery
# 1004                           1000 mAh Battery
# 1007                           3000 mAh Battery
# 1019                           1100 mAh Battery
#
#                                                 battery  \
# 85    6.1 inches, 1170 x 2532 px Display with Large ...
# 117                  5.4 inches, 1080 x 2340 px Display
# 124             3300 mAh Battery with 15W Fast Charging
# 219   6.1 inches, 1170 x 2532 px Display with Large ...
# 242             4400 mAh Battery with 25W Fast Charging
# 244                  5.4 inches, 1080 x 2340 px Display
# 266                   4.7 inches, 750 x 1334 px Display
# 270                                      No Rear Camera
# 288                           48 MB RAM, 128 MB inbuilt
# 313             4700 mAh Battery with 66W Fast Charging
# 326             3700 mAh Battery with 25W Fast Charging
# 334                                    1020 mAh Battery
# 347                 4000 mAh Battery with Fast Charging
# 349                                     800 mAh Battery
# 360   6.1 inches, 1170 x 2532 px Display with Large ...
# 370                                     800 mAh Battery
# 372                           48 MB RAM, 128 MB inbuilt
# 402                           64 MB RAM, 128 MB inbuilt
# 428                   1.77 inches, 128 x 160 px Display
# 438             4400 mAh Battery with 25W Fast Charging
# 443                    1.8 inches, 160 x 128 px Display
# 475                           48 MB RAM, 128 MB inbuilt
# 478                    1.8 inches, 160 x 128 px Display
# 493                                    1000 mAh Battery
# 494                           48 MB RAM, 128 MB inbuilt
# 506   6.1 inches, 1170 x 2532 px Display with Large ...
# 524                            32 MB RAM, 32 MB inbuilt
# 527             4400 mAh Battery with 25W Fast Charging
# 533                   4.7 inches, 750 x 1334 px Display
# 546                  5.4 inches, 1080 x 2340 px Display
# 550                    2.4 inches, 240 x 320 px Display
# 555                    1.5 inches, 128 x 128 px Display
# 564                    1.8 inches, 320 x 480 px Display
# 586   6.1 inches, 1170 x 2532 px Display with Large ...
# 589                                    1020 mAh Battery
# 607             4400 mAh Battery with 25W Fast Charging
# 610                   1.77 inches, 240 x 320 px Display
# 617                                  0.3 MP Rear Camera
# 641                    2.4 inches, 240 x 360 px Display
# 653                   4.7 inches, 750 x 1334 px Display
# 663             3300 mAh Battery with 15W Fast Charging
# 697                            32 MB RAM, 32 MB inbuilt
# 698                          512 MB RAM, 512 MB inbuilt
# 703             3700 mAh Battery with 25W Fast Charging
# 708                    2.4 inches, 320 x 240 px Display
# 710                                    2575 mAh Battery
# 711                    2.8 inches, 320 x 240 px Display
# 722                            32 MB RAM, 32 MB inbuilt
# 735                              4 MB RAM, 4 MB inbuilt
# 739                                     800 mAh Battery
# 746                          512 MB RAM, 512 MB inbuilt
# 748                            32 MB RAM, 64 MB inbuilt
# 768                                     620 mAh Battery
# 770                                    1900 mAh Battery
# 774                   1.77 inches, 128 x 160 px Display
# 775                    1.8 inches, 160 x 128 px Display
# 776                   1.77 inches, 128 x 160 px Display
# 778                   1.77 inches, 128 x 160 px Display
# 780                    2.4 inches, 160 x 128 px Display
# 783                      5 inches, 480 x 854 px Display
# 787                    1.8 inches, 160 x 128 px Display
# 790                                  0.3 MP Rear Camera
# 792             4400 mAh Battery with 25W Fast Charging
# 794                    2.4 inches, 240 x 320 px Display
# 795                    1.8 inches, 320 x 480 px Display
# 800                      Single Core, 1.1 MHz Processor
# 811                    2.4 inches, 320 x 240 px Display
# 835                             4 GB RAM, 64 GB inbuilt
# 857                                     800 mAh Battery
# 859                    1.8 inches, 128 x 160 px Display
# 861                                      No Rear Camera
# 862                   1.77 inches, 120 x 160 px Display
# 863                   1.77 inches, 120 x 160 px Display
# 865                                  0.3 MP Rear Camera
# 866                            32 MB RAM, 64 MB inbuilt
# 867                    2.4 inches, 240 x 320 px Display
# 868                                  0.3 MP Rear Camera
# 869                                   512 MHz Processor
# 872                    2.4 inches, 240 x 320 px Display
# 873                              4 MB RAM, 4 MB inbuilt
# 877                    1.8 inches, 160 x 128 px Display
# 886                    2.4 inches, 180 x 260 px Display
# 895                    3.5 inches, 240 x 320 px Display
# 897                   1.77 inches, 160 x 128 px Display
# 898                                    2500 mAh Battery
# 899                   1.77 inches, 160 x 128 px Display
# 911                                    2500 mAh Battery
# 929   6.7 inches, 1284 x 2778 px Display with Large ...
# 932                    1.8 inches, 160 x 128 px Display
# 952                                  0.3 MP Rear Camera
# 956                   1.77 inches, 128 x 160 px Display
# 964                            32 MB RAM, 32 MB inbuilt
# 971                            32 MB RAM, 32 MB inbuilt
# 972                            32 MB RAM, 32 MB inbuilt
# 979                                    1200 mAh Battery
# 993                                    1000 mAh Battery
# 994                            32 MB RAM, 32 MB inbuilt
# 999                            32 MB RAM, 32 MB inbuilt
# 1000                                   2500 mAh Battery
# 1002                            8 MB RAM, 16 MB inbuilt
# 1003                   1.8 inches, 180 x 220 px Display
# 1004                   1.8 inches, 180 x 220 px Display
# 1007                  1.77 inches, 240 x 320 px Display
# 1019                  1.44 inches, 240 x 320 px Display
#
#                                                 display  \
# 85         12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 117        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 124   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 219        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 242   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 244        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                      12 MP Rear & 7 MP Front Camera
# 270                                         No FM Radio
# 288                                    1450 mAh Battery
# 313         6.74 inches, 1212 x 2616 px, 120 Hz Display
# 326   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 334                    1.8 inches, 120 x 160 px Display
# 347                  6.8 inches, 1080 x 2460 px Display
# 349                   1.77 inches, 120 x 160 px Display
# 360   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 370                      2 inches, 128 x 160 px Display
# 372                                    1450 mAh Battery
# 402                                    1900 mAh Battery
# 428                                      No Rear Camera
# 438   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 443                                      No Rear Camera
# 475                                    1200 mAh Battery
# 478                                      No Rear Camera
# 493                   1.77 inches, 120 x 160 px Display
# 494                                    1450 mAh Battery
# 506        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 524                 1000 mAh Battery with Fast Charging
# 527   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 533                      12 MP Rear & 7 MP Front Camera
# 546        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 550                                  0.3 MP Rear Camera
# 555                                      No Rear Camera
# 564                                  1.3 MP Rear Camera
# 586   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 589                    2.4 inches, 240 x 320 px Display
# 607   7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 610                                  0.3 MP Rear Camera
# 617                   Memory Card Supported, upto 32 GB
# 641                                  0.3 MP Rear Camera
# 653                      12 MP Rear & 7 MP Front Camera
# 663   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 697                                     800 mAh Battery
# 698                                    2575 mAh Battery
# 703   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 708                                  0.3 MP Rear Camera
# 710                   1.77 inches, 160 x 128 px Display
# 711                                  1.3 MP Rear Camera
# 722                                    1200 mAh Battery
# 735                                    1020 mAh Battery
# 739                   1.77 inches, 120 x 160 px Display
# 746                                    1750 mAh Battery
# 748                                    3600 mAh Battery
# 768                    1.8 inches, 160 x 128 px Display
# 770                    1.8 inches, 128 x 160 px Display
# 774                                      No Rear Camera
# 775                                  0.3 MP Rear Camera
# 776                                      No Rear Camera
# 778                                      No Rear Camera
# 780                                  0.3 MP Rear Camera
# 783                       5 MP Rear & 2 MP Front Camera
# 787                                  0.3 MP Rear Camera
# 790                   Memory Card Supported, upto 16 GB
# 792   7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 794                                  0.3 MP Rear Camera
# 795                                  1.3 MP Rear Camera
# 800                            64 MB RAM, 64 MB inbuilt
# 811                                  0.8 MP Rear Camera
# 835             4300 mAh Battery with 30W Fast Charging
# 857                   1.45 inches, 128 x 128 px Display
# 859                                  0.3 MP Rear Camera
# 861                   Memory Card Supported, upto 16 GB
# 862                                      No Rear Camera
# 863                                  0.3 MP Rear Camera
# 865                    Memory Card Supported, upto 8 GB
# 866                                    1000 mAh Battery
# 867                                  0.3 MP Rear Camera
# 868                    Memory Card Supported, upto 8 GB
# 869                            20 MB RAM, 20 MB inbuilt
# 872                                  0.3 MP Rear Camera
# 873                                    1000 mAh Battery
# 877                                      No Rear Camera
# 886                                  0.3 MP Rear Camera
# 895                                  0.3 MP Rear Camera
# 897                                      No Rear Camera
# 898                    2.8 inches, 320 x 240 px Display
# 899                                  0.3 MP Rear Camera
# 911                    2.8 inches, 320 x 240 px Display
# 929   12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 932                                      No Rear Camera
# 952                   Memory Card Supported, upto 32 GB
# 956                                      No Rear Camera
# 964                                     800 mAh Battery
# 971                                     700 mAh Battery
# 972                                     300 mAh Battery
# 979                    2.4 inches, 240 x 320 px Display
# 993                      3 inches, 240 x 320 px Display
# 994                                    2500 mAh Battery
# 999                                    2500 mAh Battery
# 1000                   2.4 inches, 320 x 480 px Display
# 1002                                   2500 mAh Battery
# 1003                                     No Rear Camera
# 1004                                 0.3 MP Rear Camera
# 1007                                 0.3 MP Rear Camera
# 1019                                 0.3 MP Rear Camera
#
#                                                  camera  \
# 85                            Memory Card Not Supported
# 117                           Memory Card Not Supported
# 124                      Foldable Display, Dual Display
# 219                           Memory Card Not Supported
# 242                      Foldable Display, Dual Display
# 244                           Memory Card Not Supported
# 266                           Memory Card Not Supported
# 270                                                 NaN
# 288                    2.8 inches, 240 x 320 px Display
# 313   50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 326                      Foldable Display, Dual Display
# 334                                  0.3 MP Rear Camera
# 347                                        Dual Display
# 349                                      No Rear Camera
# 360                           Memory Card Not Supported
# 370                                      No Rear Camera
# 372                    2.8 inches, 240 x 320 px Display
# 402                    2.4 inches, 240 x 320 px Display
# 428                   Memory Card Supported, upto 32 GB
# 438                      Foldable Display, Dual Display
# 443                   Memory Card Supported, upto 32 GB
# 475                    2.4 inches, 240 x 320 px Display
# 478                   Memory Card Supported, upto 32 GB
# 493                   Memory Card Supported, upto 32 GB
# 494                    2.4 inches, 240 x 320 px Display
# 506                           Memory Card Not Supported
# 524                    1.8 inches, 320 x 240 px Display
# 527                      Foldable Display, Dual Display
# 533                           Memory Card Not Supported
# 546                           Memory Card Not Supported
# 550                   Memory Card Supported, upto 32 GB
# 555                                         No FM Radio
# 564                                         No FM Radio
# 586                           Memory Card Not Supported
# 589                                  0.3 MP Rear Camera
# 607                      Foldable Display, Dual Display
# 610                                         No FM Radio
# 617                                           Bluetooth
# 641                  Memory Card Supported, upto 128 GB
# 653                           Memory Card Not Supported
# 663                      Foldable Display, Dual Display
# 697                   1.77 inches, 240 x 320 px Display
# 698                    2.8 inches, 320 x 240 px Display
# 703                      Foldable Display, Dual Display
# 708                   Memory Card Supported, upto 32 GB
# 710                                  0.3 MP Rear Camera
# 711                                         No FM Radio
# 722                    2.4 inches, 320 x 240 px Display
# 735                    2.4 inches, 320 x 240 px Display
# 739                   Memory Card Supported, upto 32 GB
# 746                    2.8 inches, 320 x 240 px Display
# 748                    2.4 inches, 240 x 320 px Display
# 768                                      No Rear Camera
# 770                                  0.3 MP Rear Camera
# 774                   Memory Card Supported, upto 32 GB
# 775                   Memory Card Supported, upto 32 GB
# 776                                           Bluetooth
# 778                                           Bluetooth
# 780                   Memory Card Supported, upto 32 GB
# 783                  Memory Card Supported, upto 256 GB
# 787                   Memory Card Supported, upto 32 GB
# 790                                           Bluetooth
# 792                      Foldable Display, Dual Display
# 794                               Memory Card Supported
# 795                    Memory Card (Hybrid), upto 32 GB
# 800                                    2500 mAh Battery
# 811                   Memory Card Supported, upto 64 GB
# 835   6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 857                                      No Rear Camera
# 859                   Memory Card Supported, upto 32 GB
# 861                                                 NaN
# 862                   Memory Card Supported, upto 32 GB
# 863                   Memory Card Supported, upto 32 GB
# 865                                           Bluetooth
# 866                   1.77 inches, 240 x 320 px Display
# 867                                         No FM Radio
# 868                                           Bluetooth
# 869                                    2575 mAh Battery
# 872                   Memory Card Supported, upto 32 GB
# 873                    1.8 inches, 160 x 128 px Display
# 877                   Memory Card Supported, upto 32 GB
# 886                    Memory Card Supported, upto 8 GB
# 895                   Memory Card Supported, upto 32 GB
# 897                   Memory Card Supported, upto 32 GB
# 898                                    2 MP Rear Camera
# 899                   Memory Card Supported, upto 32 GB
# 911                                  0.3 MP Rear Camera
# 929                           Memory Card Not Supported
# 932                   Memory Card Supported, upto 32 GB
# 952                                           Bluetooth
# 956                                           Bluetooth
# 964                   0.66 inches, 128 x 160 px Display
# 971                    2.4 inches, 240 x 320 px Display
# 972                     0.66 inches, 64 x 48 px Display
# 979                                    2 MP Rear Camera
# 993                                  3.2 MP Rear Camera
# 994                    2.4 inches, 320 x 480 px Display
# 999                    2.8 inches, 240 x 320 px Display
# 1000                                 0.3 MP Rear Camera
# 1002                   2.4 inches, 128 x 160 px Display
# 1003                  Memory Card Supported, upto 32 GB
# 1004                  Memory Card Supported, upto 32 GB
# 1007                                        No FM Radio
# 1019                  Memory Card Supported, upto 32 GB
#
#                                                    card  \
# 85                                              iOS v14
# 117                                             iOS v14
# 124        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 219                                             iOS v14
# 242   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 244                                             iOS v14
# 266                                             iOS v15
# 270                                                 NaN
# 288                                        Dual Display
# 313                   Memory Card (Hybrid), upto 256 GB
# 326        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 334                   Memory Card Supported, upto 32 GB
# 347   64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 349                                                 NaN
# 360                                           iOS v14.0
# 370                   Memory Card Supported, upto 16 GB
# 372                                  0.3 MP Rear Camera
# 402                                  1.3 MP Rear Camera
# 428                                           Bluetooth
# 438   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 443                                           Bluetooth
# 475                                  1.3 MP Rear Camera
# 478                                                 NaN
# 493                                                 NaN
# 494                                  0.3 MP Rear Camera
# 506                                             iOS v14
# 524                                    2 MP Rear Camera
# 527   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 533                                             iOS v15
# 546                                             iOS v14
# 550                                           Bluetooth
# 555                                                 NaN
# 564                                                 NaN
# 586                                           iOS v14.0
# 589                   Memory Card Supported, upto 32 GB
# 607   50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 610                                                 NaN
# 617                                             Browser
# 641                                           Bluetooth
# 653                                             iOS v15
# 663        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 697                                        Dual Display
# 698                                  1.3 MP Rear Camera
# 703        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 708                                                 NaN
# 710                   Memory Card Supported, upto 32 GB
# 711                                                 NaN
# 722                                 0.08 MP Rear Camera
# 735                                      No Rear Camera
# 739                                                 NaN
# 746                                  1.3 MP Rear Camera
# 748                       0.3 MP Rear & No Front Camera
# 768                   Memory Card Supported, upto 32 GB
# 770                   Memory Card Supported, upto 64 GB
# 774                                           Bluetooth
# 775                                                 NaN
# 776                                                 NaN
# 778                                                 NaN
# 780                                           Bluetooth
# 783                                         Android v11
# 787                                                 NaN
# 790                                                 NaN
# 792   12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 794                                         No FM Radio
# 795                                         No FM Radio
# 800                    2.6 inches, 240 x 320 px Display
# 811                                           Bluetooth
# 835                48 MP Quad Rear & 16 MP Front Camera
# 857                           Memory Card Not Supported
# 859                                           Bluetooth
# 861                                                 NaN
# 862                                                 NaN
# 863                                                 NaN
# 865                                                 NaN
# 866                                      No Rear Camera
# 867                                           Bluetooth
# 868                                                 NaN
# 869                    2.8 inches, 245 x 320 px Display
# 872                                           Bluetooth
# 873                                      No Rear Camera
# 877                                           Bluetooth
# 886                                           Bluetooth
# 895                                             Browser
# 897                                           Bluetooth
# 898                   Memory Card Supported, upto 32 GB
# 899                                           Bluetooth
# 911                   Memory Card Supported, upto 32 GB
# 929                                           iOS v14.0
# 932                                           Bluetooth
# 952                                                 NaN
# 956                                                 NaN
# 964                                      No Rear Camera
# 971                       0.3 MP Rear & No Front Camera
# 972                                  0.2 MP Rear Camera
# 979                   Memory Card Supported, upto 32 GB
# 993                   Memory Card Supported, upto 32 GB
# 994                                  1.3 MP Rear Camera
# 999                       1.3 MP Rear & No Front Camera
# 1000                                          Bluetooth
# 1002                                 0.3 MP Rear Camera
# 1003                                          Bluetooth
# 1004                                          Bluetooth
# 1007                                                NaN
# 1019                                          Bluetooth
#
#                                       os
# 85                           No FM Radio
# 117                          No FM Radio
# 124            Memory Card Not Supported
# 219                          No FM Radio
# 242                          Android v12
# 244                          No FM Radio
# 266                          No FM Radio
# 270                                  NaN
# 288                   0.3 MP Rear Camera
# 313                     Hongmeng OS v3.0
# 326            Memory Card Not Supported
# 334                                  NaN
# 347      Memory Card (Hybrid), upto 2 TB
# 349                                  NaN
# 360                          No FM Radio
# 370                                  NaN
# 372    Memory Card Supported, upto 32 GB
# 402    Memory Card Supported, upto 64 GB
# 428                                  NaN
# 438                          Android v11
# 443                                  NaN
# 475    Memory Card Supported, upto 64 GB
# 478                                  NaN
# 493                                  NaN
# 494    Memory Card Supported, upto 32 GB
# 506                          No FM Radio
# 524                Memory Card Supported
# 527                          Android v12
# 533                          No FM Radio
# 546                          No FM Radio
# 550                              Browser
# 555                                  NaN
# 564                                  NaN
# 586                          No FM Radio
# 589                            Bluetooth
# 607                          Android v12
# 610                                  NaN
# 617                                  NaN
# 641                              Browser
# 653                          No FM Radio
# 663            Memory Card Not Supported
# 697                   1.3 MP Rear Camera
# 698    Memory Card Supported, upto 32 GB
# 703            Memory Card Not Supported
# 708                                  NaN
# 710                            Bluetooth
# 711                                  NaN
# 722    Memory Card Supported, upto 32 GB
# 735                Memory Card Supported
# 739                                  NaN
# 746    Memory Card Supported, upto 32 GB
# 748    Memory Card Supported, upto 32 GB
# 768                                  NaN
# 770                                Mocor
# 774                                  NaN
# 775                                  NaN
# 776                                  NaN
# 778                                  NaN
# 780                                  NaN
# 783                            Bluetooth
# 787                                  NaN
# 790                                  NaN
# 792                          Android v11
# 794                                  NaN
# 795                                  NaN
# 800                     2 MP Rear Camera
# 811                                  NaN
# 835   Memory Card Supported, upto 256 GB
# 857                                  NaN
# 859                                  NaN
# 861                                  NaN
# 862                                  NaN
# 863                                  NaN
# 865                                  NaN
# 866                Memory Card Supported
# 867                                  NaN
# 868                                  NaN
# 869                   1.3 MP Rear Camera
# 872                                  NaN
# 873    Memory Card Supported, upto 32 GB
# 877                                  NaN
# 886                                  NaN
# 895                                  NaN
# 897                                  NaN
# 898                            Bluetooth
# 899                                  NaN
# 911                            Bluetooth
# 929                          No FM Radio
# 932                                  NaN
# 952                                  NaN
# 956                                  NaN
# 964    Memory Card Supported, upto 16 GB
# 971    Memory Card Supported, upto 32 GB
# 972                Memory Card Supported
# 979                            Bluetooth
# 993                            Bluetooth
# 994                            Bluetooth
# 999    Memory Card Supported, upto 32 GB
# 1000                                 NaN
# 1002                           Bluetooth
# 1003                                 NaN
# 1004                                 NaN
# 1007                                 NaN
# 1019                                 NaN

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#       index                           model  price  rating  \
# 270     272           Samsung Guru GT-E1215   1599     NaN
# 288     290                 Nokia 2660 Flip   4649     NaN
# 372     374                   Nokia 8210 4G   3749     NaN
# 402     404                 itel Magic 2 4G   2399     NaN
# 443     445                    itel it2163S    958     NaN
# 475     477                    itel Magic X   2239     NaN
# 478     480               Motorola Moto A10   1339     NaN
# 494     496          Nokia 5710 XpressAudio   4799     NaN
# 524     526               GreenBerry Rafale    899     NaN
# 555     557              Samsung Guru E1200   1685     NaN
# 564     566                Kechaoda K55 Pro   1180     NaN
# 610     612              Micromax X513 Plus    949     NaN
# 617     619                  Itel Power 700   1899     NaN
# 697     699                 XTouch F40 Flip   1999     NaN
# 698     700                  Lava Gem Power   1977     NaN
# 708     710               Motorola Moto A70   1960     NaN
# 711     713                    itel Magic 3   1498     NaN
# 735     737                       Nokia 125   2099     NaN
# 746     748                        Lava Gem   1499     NaN
# 748     750                   Kechaoda K112   1618     NaN
# 774     776       Nokia 105 Plus Single Sim   1399     NaN
# 776     778         Nokia 105 Dual Sim 2022   1449     NaN
# 778     780                  Nokia 105 2022   1299     NaN
# 780     782                    Lava A7 Star   1529     NaN
# 783     785                        Lava Z21   5299     NaN
# 787     789               Motorola Moto A50   1584     NaN
# 790     792             Philips Xenium E125   1349     NaN
# 794     796                 iKall K24 Ultra   1049     NaN
# 795     797  Kechaoda K66 The Music House 4   1160     NaN
# 800     802                  Karbonn K9 Max   1429     NaN
# 835     837                       Realme 6i  12390    75.0
# 859     861                  itel Power 200   1379     NaN
# 861     863                    Mafe X1 Plus    999     NaN
# 862     864                    BlackZone C9    899     NaN
# 863     865                    BlackZone C6   1049     NaN
# 865     867              Itel Power 110 Neo   1325     NaN
# 866     868                   Micromax S114   1128     NaN
# 867     869              Kechaoda K102 Plus   1299     NaN
# 868     870                 Itel Power 110N   1325     NaN
# 869     871                     Lava LF9000   1880     NaN
# 872     874                  Itel Power 430   1499     NaN
# 873     875                 itel Ace 2 Star    899     NaN
# 886     888                         Vox V14    883     NaN
# 895     897                     Kechaoda A6   1449     NaN
# 897     899               Lava A1 Josh 2021   1139     NaN
# 899     901                    Lava A1 2021   1079     NaN
# 956     958       Nokia 105 Dual SIM (2019)   1299     NaN
# 971     973                 Easyfone Royale   3499     NaN
# 972     974                    Kechaoda K10   1160     NaN
# 994     996              Telefono S1 Dazzle    899     NaN
# 999    1001                Snexian Bold 12K   1499     NaN
# 1002   1004                Telefono T1 Star    949     NaN
# 1003   1005                   iKall K15 New    849     NaN
# 1004   1006                   iKall K52 New    839     NaN
# 1019   1021                          MTR M7   1050     NaN
#
#                                  sim                 processor  \
# 270                       Single Sim           800 mAh Battery
# 288                 Dual Sim, 3G, 4G                   No Wifi
# 372                 Dual Sim, 3G, 4G                   No Wifi
# 402   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                     No 3G
# 443                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 475   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                     No 3G
# 478                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 494                 Dual Sim, 3G, 4G                   No Wifi
# 524                         Dual Sim                     No 3G
# 555                       Single Sim                   No Wifi
# 564                         Dual Sim  32 MB RAM, 64 MB inbuilt
# 610                         Dual Sim  32 MB RAM, 32 MB inbuilt
# 617                       Triple Sim          2500 mAh Battery
# 697                         Dual Sim                     No 3G
# 698                         Dual Sim                     No 3G
# 708                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 711                         Dual Sim    8 MB RAM, 8 MB inbuilt
# 735                         Dual Sim                   No Wifi
# 746                         Dual Sim                     No 3G
# 748                       Triple Sim                     No 3G
# 774                       Single Sim    4 MB RAM, 4 MB inbuilt
# 776                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 778                       Single Sim    4 MB RAM, 4 MB inbuilt
# 780                         Dual Sim  24 MB RAM, 32 MB inbuilt
# 783   Dual Sim, 3G, 4G, VoLTE, Wi-Fi   2 GB RAM, 32 GB inbuilt
# 787                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 790              Dual Sim, 3G, Wi-Fi          2000 mAh Battery
# 794                         Dual Sim  32 MB RAM, 32 MB inbuilt
# 795                         Dual Sim  32 MB RAM, 64 MB inbuilt
# 800                         Dual Sim                     No 3G
# 835   Dual Sim, 3G, 4G, VoLTE, Wi-Fi                   No Wifi
# 859                         Dual Sim  32 MB RAM, 32 MB inbuilt
# 861                         Dual Sim          1050 mAh Battery
# 862                         Dual Sim  32 MB RAM, 32 MB inbuilt
# 863                         Dual Sim  64 MB RAM, 64 MB inbuilt
# 865                         Dual Sim          2500 mAh Battery
# 866                         Dual Sim                     No 3G
# 867                         Dual Sim  32 MB RAM, 64 MB inbuilt
# 868                         Dual Sim          2500 mAh Battery
# 869                         Dual Sim                     No 3G
# 872                         Dual Sim    8 MB RAM, 8 MB inbuilt
# 873                         Dual Sim                     No 3G
# 886                         Dual Sim  32 MB RAM, 32 MB inbuilt
# 895                       Triple Sim              4 MB inbuilt
# 897                         Dual Sim  32 MB RAM, 24 MB inbuilt
# 899                         Dual Sim  32 MB RAM, 24 MB inbuilt
# 956                         Dual Sim    4 MB RAM, 4 MB inbuilt
# 971                       Single Sim                     No 3G
# 972                       Single Sim                     No 3G
# 994                         Dual Sim                     No 3G
# 999                         Dual Sim                   No Wifi
# 1002                        Dual Sim                     No 3G
# 1003                        Dual Sim  32 MB RAM, 64 MB inbuilt
# 1004                        Dual Sim  32 MB RAM, 64 MB inbuilt
# 1019                        Dual Sim  32 MB RAM, 32 MB inbuilt
#
#                                             ram  \
# 270            1.5 inches, 120 x 120 px Display
# 288                                 Unisoc T107
# 372                                 Unisoc T107
# 402                                        T117
# 443                            1200 mAh Battery
# 475                                        T117
# 478                            1750 mAh Battery
# 494                                 Unisoc T107
# 524                           1.2 MHz Processor
# 555                             800 mAh Battery
# 564                             400 mAh Battery
# 610                            1750 mAh Battery
# 617            2.8 inches, 320 x 240 px Display
# 697                                     No Wifi
# 698                                     No Wifi
# 708                            1750 mAh Battery
# 711                            1500 mAh Battery
# 735                                       Helio
# 746                                     No Wifi
# 748                                     No Wifi
# 774                             800 mAh Battery
# 776                             800 mAh Battery
# 778                             800 mAh Battery
# 780                            1800 mAh Battery
# 783                            3100 mAh Battery
# 787                            1750 mAh Battery
# 790           1.77 inches, 128 x 160 px Display
# 794                            2500 mAh Battery
# 795                             400 mAh Battery
# 800                                     No Wifi
# 835   Helio G90T, Octa Core, 2.05 GHz Processor
# 859                            2500 mAh Battery
# 861            1.8 inches, 128 x 160 px Display
# 862                            1100 mAh Battery
# 863                            2500 mAh Battery
# 865            1.8 inches, 128 x 160 px Display
# 866                                     No Wifi
# 867                            2500 mAh Battery
# 868            1.8 inches, 128 x 160 px Display
# 869                                     No Wifi
# 872                            2500 mAh Battery
# 873                                     No Wifi
# 886                            2500 mAh Battery
# 895                            2500 mAh Battery
# 897                             800 mAh Battery
# 899                             800 mAh Battery
# 956                             800 mAh Battery
# 971                                     No Wifi
# 972                                     No Wifi
# 994                                     No Wifi
# 999                             1 MHz Processor
# 1002                                    No Wifi
# 1003                           1000 mAh Battery
# 1004                           1000 mAh Battery
# 1019                           1100 mAh Battery
#
#                                 battery  \
# 270                      No Rear Camera
# 288           48 MB RAM, 128 MB inbuilt
# 372           48 MB RAM, 128 MB inbuilt
# 402           64 MB RAM, 128 MB inbuilt
# 443    1.8 inches, 160 x 128 px Display
# 475           48 MB RAM, 128 MB inbuilt
# 478    1.8 inches, 160 x 128 px Display
# 494           48 MB RAM, 128 MB inbuilt
# 524            32 MB RAM, 32 MB inbuilt
# 555    1.5 inches, 128 x 128 px Display
# 564    1.8 inches, 320 x 480 px Display
# 610   1.77 inches, 240 x 320 px Display
# 617                  0.3 MP Rear Camera
# 697            32 MB RAM, 32 MB inbuilt
# 698          512 MB RAM, 512 MB inbuilt
# 708    2.4 inches, 320 x 240 px Display
# 711    2.8 inches, 320 x 240 px Display
# 735              4 MB RAM, 4 MB inbuilt
# 746          512 MB RAM, 512 MB inbuilt
# 748            32 MB RAM, 64 MB inbuilt
# 774   1.77 inches, 128 x 160 px Display
# 776   1.77 inches, 128 x 160 px Display
# 778   1.77 inches, 128 x 160 px Display
# 780    2.4 inches, 160 x 128 px Display
# 783      5 inches, 480 x 854 px Display
# 787    1.8 inches, 160 x 128 px Display
# 790                  0.3 MP Rear Camera
# 794    2.4 inches, 240 x 320 px Display
# 795    1.8 inches, 320 x 480 px Display
# 800      Single Core, 1.1 MHz Processor
# 835             4 GB RAM, 64 GB inbuilt
# 859    1.8 inches, 128 x 160 px Display
# 861                      No Rear Camera
# 862   1.77 inches, 120 x 160 px Display
# 863   1.77 inches, 120 x 160 px Display
# 865                  0.3 MP Rear Camera
# 866            32 MB RAM, 64 MB inbuilt
# 867    2.4 inches, 240 x 320 px Display
# 868                  0.3 MP Rear Camera
# 869                   512 MHz Processor
# 872    2.4 inches, 240 x 320 px Display
# 873              4 MB RAM, 4 MB inbuilt
# 886    2.4 inches, 180 x 260 px Display
# 895    3.5 inches, 240 x 320 px Display
# 897   1.77 inches, 160 x 128 px Display
# 899   1.77 inches, 160 x 128 px Display
# 956   1.77 inches, 128 x 160 px Display
# 971            32 MB RAM, 32 MB inbuilt
# 972            32 MB RAM, 32 MB inbuilt
# 994            32 MB RAM, 32 MB inbuilt
# 999            32 MB RAM, 32 MB inbuilt
# 1002            8 MB RAM, 16 MB inbuilt
# 1003   1.8 inches, 180 x 220 px Display
# 1004   1.8 inches, 180 x 220 px Display
# 1019  1.44 inches, 240 x 320 px Display
#
#                                       display  \
# 270                               No FM Radio
# 288                          1450 mAh Battery
# 372                          1450 mAh Battery
# 402                          1900 mAh Battery
# 443                            No Rear Camera
# 475                          1200 mAh Battery
# 478                            No Rear Camera
# 494                          1450 mAh Battery
# 524       1000 mAh Battery with Fast Charging
# 555                            No Rear Camera
# 564                        1.3 MP Rear Camera
# 610                        0.3 MP Rear Camera
# 617         Memory Card Supported, upto 32 GB
# 697                           800 mAh Battery
# 698                          2575 mAh Battery
# 708                        0.3 MP Rear Camera
# 711                        1.3 MP Rear Camera
# 735                          1020 mAh Battery
# 746                          1750 mAh Battery
# 748                          3600 mAh Battery
# 774                            No Rear Camera
# 776                            No Rear Camera
# 778                            No Rear Camera
# 780                        0.3 MP Rear Camera
# 783             5 MP Rear & 2 MP Front Camera
# 787                        0.3 MP Rear Camera
# 790         Memory Card Supported, upto 16 GB
# 794                        0.3 MP Rear Camera
# 795                        1.3 MP Rear Camera
# 800                  64 MB RAM, 64 MB inbuilt
# 835   4300 mAh Battery with 30W Fast Charging
# 859                        0.3 MP Rear Camera
# 861         Memory Card Supported, upto 16 GB
# 862                            No Rear Camera
# 863                        0.3 MP Rear Camera
# 865          Memory Card Supported, upto 8 GB
# 866                          1000 mAh Battery
# 867                        0.3 MP Rear Camera
# 868          Memory Card Supported, upto 8 GB
# 869                  20 MB RAM, 20 MB inbuilt
# 872                        0.3 MP Rear Camera
# 873                          1000 mAh Battery
# 886                        0.3 MP Rear Camera
# 895                        0.3 MP Rear Camera
# 897                            No Rear Camera
# 899                        0.3 MP Rear Camera
# 956                            No Rear Camera
# 971                           700 mAh Battery
# 972                           300 mAh Battery
# 994                          2500 mAh Battery
# 999                          2500 mAh Battery
# 1002                         2500 mAh Battery
# 1003                           No Rear Camera
# 1004                       0.3 MP Rear Camera
# 1019                       0.3 MP Rear Camera
#
#                                                  camera  \
# 270                                                 NaN
# 288                    2.8 inches, 240 x 320 px Display
# 372                    2.8 inches, 240 x 320 px Display
# 402                    2.4 inches, 240 x 320 px Display
# 443                   Memory Card Supported, upto 32 GB
# 475                    2.4 inches, 240 x 320 px Display
# 478                   Memory Card Supported, upto 32 GB
# 494                    2.4 inches, 240 x 320 px Display
# 524                    1.8 inches, 320 x 240 px Display
# 555                                         No FM Radio
# 564                                         No FM Radio
# 610                                         No FM Radio
# 617                                           Bluetooth
# 697                   1.77 inches, 240 x 320 px Display
# 698                    2.8 inches, 320 x 240 px Display
# 708                   Memory Card Supported, upto 32 GB
# 711                                         No FM Radio
# 735                    2.4 inches, 320 x 240 px Display
# 746                    2.8 inches, 320 x 240 px Display
# 748                    2.4 inches, 240 x 320 px Display
# 774                   Memory Card Supported, upto 32 GB
# 776                                           Bluetooth
# 778                                           Bluetooth
# 780                   Memory Card Supported, upto 32 GB
# 783                  Memory Card Supported, upto 256 GB
# 787                   Memory Card Supported, upto 32 GB
# 790                                           Bluetooth
# 794                               Memory Card Supported
# 795                    Memory Card (Hybrid), upto 32 GB
# 800                                    2500 mAh Battery
# 835   6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 859                   Memory Card Supported, upto 32 GB
# 861                                                 NaN
# 862                   Memory Card Supported, upto 32 GB
# 863                   Memory Card Supported, upto 32 GB
# 865                                           Bluetooth
# 866                   1.77 inches, 240 x 320 px Display
# 867                                         No FM Radio
# 868                                           Bluetooth
# 869                                    2575 mAh Battery
# 872                   Memory Card Supported, upto 32 GB
# 873                    1.8 inches, 160 x 128 px Display
# 886                    Memory Card Supported, upto 8 GB
# 895                   Memory Card Supported, upto 32 GB
# 897                   Memory Card Supported, upto 32 GB
# 899                   Memory Card Supported, upto 32 GB
# 956                                           Bluetooth
# 971                    2.4 inches, 240 x 320 px Display
# 972                     0.66 inches, 64 x 48 px Display
# 994                    2.4 inches, 320 x 480 px Display
# 999                    2.8 inches, 240 x 320 px Display
# 1002                   2.4 inches, 128 x 160 px Display
# 1003                  Memory Card Supported, upto 32 GB
# 1004                  Memory Card Supported, upto 32 GB
# 1019                  Memory Card Supported, upto 32 GB
#
#                                       card                                  os
# 270                                    NaN                                 NaN
# 288                           Dual Display                  0.3 MP Rear Camera
# 372                     0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 402                     1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 443                              Bluetooth                                 NaN
# 475                     1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 478                                    NaN                                 NaN
# 494                     0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 524                       2 MP Rear Camera               Memory Card Supported
# 555                                    NaN                                 NaN
# 564                                    NaN                                 NaN
# 610                                    NaN                                 NaN
# 617                                Browser                                 NaN
# 697                           Dual Display                  1.3 MP Rear Camera
# 698                     1.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 708                                    NaN                                 NaN
# 711                                    NaN                                 NaN
# 735                         No Rear Camera               Memory Card Supported
# 746                     1.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 748          0.3 MP Rear & No Front Camera   Memory Card Supported, upto 32 GB
# 774                              Bluetooth                                 NaN
# 776                                    NaN                                 NaN
# 778                                    NaN                                 NaN
# 780                              Bluetooth                                 NaN
# 783                            Android v11                           Bluetooth
# 787                                    NaN                                 NaN
# 790                                    NaN                                 NaN
# 794                            No FM Radio                                 NaN
# 795                            No FM Radio                                 NaN
# 800       2.6 inches, 240 x 320 px Display                    2 MP Rear Camera
# 835   48 MP Quad Rear & 16 MP Front Camera  Memory Card Supported, upto 256 GB
# 859                              Bluetooth                                 NaN
# 861                                    NaN                                 NaN
# 862                                    NaN                                 NaN
# 863                                    NaN                                 NaN
# 865                                    NaN                                 NaN
# 866                         No Rear Camera               Memory Card Supported
# 867                              Bluetooth                                 NaN
# 868                                    NaN                                 NaN
# 869       2.8 inches, 245 x 320 px Display                  1.3 MP Rear Camera
# 872                              Bluetooth                                 NaN
# 873                         No Rear Camera   Memory Card Supported, upto 32 GB
# 886                              Bluetooth                                 NaN
# 895                                Browser                                 NaN
# 897                              Bluetooth                                 NaN
# 899                              Bluetooth                                 NaN
# 956                                    NaN                                 NaN
# 971          0.3 MP Rear & No Front Camera   Memory Card Supported, upto 32 GB
# 972                     0.2 MP Rear Camera               Memory Card Supported
# 994                     1.3 MP Rear Camera                           Bluetooth
# 999          1.3 MP Rear & No Front Camera   Memory Card Supported, upto 32 GB
# 1002                    0.3 MP Rear Camera                           Bluetooth
# 1003                             Bluetooth                                 NaN
# 1004                             Bluetooth                                 NaN
# 1019                             Bluetooth                                 NaN

# %%
df1.shape
# Out:
# (1020, 12)

# %%
# Removing All the Feature phones and keep only Smartphones

df1 = df1[df1['price'] >= 3500]

# %%
df1.shape
# Out:
# (885, 12)

# %%
df1[df1['index'].isin(processor_rows & ram_rows & battery_rows & display_rows & camera_rows)]
# Out:
#      index                   model  price  rating  \
# 288    290         Nokia 2660 Flip   4649     NaN
# 372    374           Nokia 8210 4G   3749     NaN
# 494    496  Nokia 5710 XpressAudio   4799     NaN
# 783    785                Lava Z21   5299     NaN
# 835    837               Realme 6i  12390    75.0
#
#                                 sim                processor  \
# 288                Dual Sim, 3G, 4G                  No Wifi
# 372                Dual Sim, 3G, 4G                  No Wifi
# 494                Dual Sim, 3G, 4G                  No Wifi
# 783  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  2 GB RAM, 32 GB inbuilt
# 835  Dual Sim, 3G, 4G, VoLTE, Wi-Fi                  No Wifi
#
#                                            ram  \
# 288                                Unisoc T107
# 372                                Unisoc T107
# 494                                Unisoc T107
# 783                           3100 mAh Battery
# 835  Helio G90T, Octa Core, 2.05 GHz Processor
#
#                             battery                                  display  \
# 288       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 372       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 494       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 783  5 inches, 480 x 854 px Display            5 MP Rear & 2 MP Front Camera
# 835         4 GB RAM, 64 GB inbuilt  4300 mAh Battery with 30W Fast Charging
#
#                                                 camera  \
# 288                   2.8 inches, 240 x 320 px Display
# 372                   2.8 inches, 240 x 320 px Display
# 494                   2.4 inches, 240 x 320 px Display
# 783                 Memory Card Supported, upto 256 GB
# 835  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
#
#                                      card                                  os
# 288                          Dual Display                  0.3 MP Rear Camera
# 372                    0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 494                    0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 783                           Android v11                           Bluetooth
# 835  48 MP Quad Rear & 16 MP Front Camera  Memory Card Supported, upto 256 GB

# %% [markdown]
# **Cleaning Processor Column**

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
#      index                      model  price  rating  \
# 288    290            Nokia 2660 Flip   4649     NaN
# 372    374              Nokia 8210 4G   3749     NaN
# 494    496     Nokia 5710 XpressAudio   4799     NaN
# 783    785                   Lava Z21   5299     NaN
# 835    837                  Realme 6i  12390    75.0
# 979    981          Nokia 3310 (2017)   3699     NaN
# 993    995  Samsung Star 3 Duos S5222   8990     NaN
#
#                                 sim                processor  \
# 288                Dual Sim, 3G, 4G                  No Wifi
# 372                Dual Sim, 3G, 4G                  No Wifi
# 494                Dual Sim, 3G, 4G                  No Wifi
# 783  Dual Sim, 3G, 4G, VoLTE, Wi-Fi  2 GB RAM, 32 GB inbuilt
# 835  Dual Sim, 3G, 4G, VoLTE, Wi-Fi                  No Wifi
# 979                        Dual Sim                  No Wifi
# 993                 Dual Sim, Wi-Fi                    No 3G
#
#                                            ram  \
# 288                                Unisoc T107
# 372                                Unisoc T107
# 494                                Unisoc T107
# 783                           3100 mAh Battery
# 835  Helio G90T, Octa Core, 2.05 GHz Processor
# 979                              16 MB inbuilt
# 993                              20 MB inbuilt
#
#                             battery                                  display  \
# 288       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 372       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 494       48 MB RAM, 128 MB inbuilt                         1450 mAh Battery
# 783  5 inches, 480 x 854 px Display            5 MP Rear & 2 MP Front Camera
# 835         4 GB RAM, 64 GB inbuilt  4300 mAh Battery with 30W Fast Charging
# 979                1200 mAh Battery         2.4 inches, 240 x 320 px Display
# 993                1000 mAh Battery           3 inches, 240 x 320 px Display
#
#                                                 camera  \
# 288                   2.8 inches, 240 x 320 px Display
# 372                   2.8 inches, 240 x 320 px Display
# 494                   2.4 inches, 240 x 320 px Display
# 783                 Memory Card Supported, upto 256 GB
# 835  6.5 inches, 1080 x 2400 px, 90 Hz Display with...
# 979                                   2 MP Rear Camera
# 993                                 3.2 MP Rear Camera
#
#                                      card                                  os
# 288                          Dual Display                  0.3 MP Rear Camera
# 372                    0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 494                    0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 783                           Android v11                           Bluetooth
# 835  48 MP Quad Rear & 16 MP Front Camera  Memory Card Supported, upto 256 GB
# 979     Memory Card Supported, upto 32 GB                           Bluetooth
# 993     Memory Card Supported, upto 32 GB                           Bluetooth

# %%
# Dropping all the features phones

df1.drop([288,372,494,783,835,979,993],inplace=True)

# %%
df1[df1['index'].isin(processor_rows)]
# Out:
# Empty DataFrame
# Columns: [index, model, price, rating, sim, processor, ram, battery, display, camera, card, os]
# Index: []

# %% [markdown]
# **Cleaning Ram Column**

# %%
df1[df1['index'].isin(ram_rows)]
# Out:
#      index                             model   price  rating  \
# 266    268            Apple iPhone SE 3 2022   43900     NaN
# 313    315  Huawei Mate 50 RS Porsche Design  239999    81.0
# 533    535    Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 653    655    Apple iPhone SE 3 2022 (256GB)   58900    61.0
#
#                                                  sim  \
# 266          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 313  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 533          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                             processor             ram  \
# 266        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 313  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 533        Bionic  A15, Hexa Core, 3.22 GHz Processor  128 GB inbuilt
# 653        Bionic  A15, Hexa Core, 3.22 GHz Processor  256 GB inbuilt
#
#                                      battery  \
# 266        4.7 inches, 750 x 1334 px Display
# 313  4700 mAh Battery with 66W Fast Charging
# 533        4.7 inches, 750 x 1334 px Display
# 653        4.7 inches, 750 x 1334 px Display
#
#                                          display  \
# 266               12 MP Rear & 7 MP Front Camera
# 313  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 533               12 MP Rear & 7 MP Front Camera
# 653               12 MP Rear & 7 MP Front Camera
#
#                                                 camera  \
# 266                          Memory Card Not Supported
# 313  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 533                          Memory Card Not Supported
# 653                          Memory Card Not Supported
#
#                                   card                os
# 266                            iOS v15       No FM Radio
# 313  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0
# 533                            iOS v15       No FM Radio
# 653                            iOS v15       No FM Radio

# %% [markdown]
# **Cleaning Battery Column**

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                            model   price  rating  \
# 244    246     Apple iPhone 12 Mini (128GB)   45999    75.0
# 266    268           Apple iPhone SE 3 2022   43900     NaN
# 360    362      Apple iPhone 12 Pro (512GB)  139900    80.0
# 506    508          Apple iPhone 12 (256GB)   67999    76.0
# 533    535   Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548     Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588      Apple iPhone 12 Pro (256GB)  119900    80.0
# 653    655   Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 929    931  Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                          sim  \
# 244  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 244    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 266  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 360    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 506    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 533  Bionic  A15, Hexa Core, 3.22 GHz Processor            128 GB inbuilt
# 546    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 586    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 653  Bionic  A15, Hexa Core, 3.22 GHz Processor            256 GB inbuilt
# 929    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
#
#                                                battery  \
# 244                 5.4 inches, 1080 x 2340 px Display
# 266                  4.7 inches, 750 x 1334 px Display
# 360  6.1 inches, 1170 x 2532 px Display with Large ...
# 506  6.1 inches, 1170 x 2532 px Display with Large ...
# 533                  4.7 inches, 750 x 1334 px Display
# 546                 5.4 inches, 1080 x 2340 px Display
# 586  6.1 inches, 1170 x 2532 px Display with Large ...
# 653                  4.7 inches, 750 x 1334 px Display
# 929  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                display  \
# 244       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                     12 MP Rear & 7 MP Front Camera
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 653                     12 MP Rear & 7 MP Front Camera
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                         camera       card           os
# 244  Memory Card Not Supported    iOS v14  No FM Radio
# 266  Memory Card Not Supported    iOS v15  No FM Radio
# 360  Memory Card Not Supported  iOS v14.0  No FM Radio
# 506  Memory Card Not Supported    iOS v14  No FM Radio
# 533  Memory Card Not Supported    iOS v15  No FM Radio
# 546  Memory Card Not Supported    iOS v14  No FM Radio
# 586  Memory Card Not Supported  iOS v14.0  No FM Radio
# 653  Memory Card Not Supported    iOS v15  No FM Radio
# 929  Memory Card Not Supported  iOS v14.0  No FM Radio

# %%
# Shifting forward all certain values of  columns by one position

temp_df = df1[df1['index'].isin(battery_rows)]
x = temp_df.iloc[:,7:].shift(1,axis=1).values
df1.loc[temp_df.index,temp_df.columns[7:]] = x

# %%
df1[df1['index'].isin(battery_rows)]
# Out:
#      index                            model   price  rating  \
# 244    246     Apple iPhone 12 Mini (128GB)   45999    75.0
# 266    268           Apple iPhone SE 3 2022   43900     NaN
# 360    362      Apple iPhone 12 Pro (512GB)  139900    80.0
# 506    508          Apple iPhone 12 (256GB)   67999    76.0
# 533    535   Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548     Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588      Apple iPhone 12 Pro (256GB)  119900    80.0
# 653    655   Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 929    931  Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                          sim  \
# 244  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 244    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 266  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 360    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 506    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 533  Bionic  A15, Hexa Core, 3.22 GHz Processor            128 GB inbuilt
# 546    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 586    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 653  Bionic  A15, Hexa Core, 3.22 GHz Processor            256 GB inbuilt
# 929    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
#
#     battery                                            display  \
# 244    None                 5.4 inches, 1080 x 2340 px Display
# 266    None                  4.7 inches, 750 x 1334 px Display
# 360    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 506    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 533    None                  4.7 inches, 750 x 1334 px Display
# 546    None                 5.4 inches, 1080 x 2340 px Display
# 586    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 653    None                  4.7 inches, 750 x 1334 px Display
# 929    None  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 camera  \
# 244       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                     12 MP Rear & 7 MP Front Camera
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 653                     12 MP Rear & 7 MP Front Camera
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card         os
# 244  Memory Card Not Supported    iOS v14
# 266  Memory Card Not Supported    iOS v15
# 360  Memory Card Not Supported  iOS v14.0
# 506  Memory Card Not Supported    iOS v14
# 533  Memory Card Not Supported    iOS v15
# 546  Memory Card Not Supported    iOS v14
# 586  Memory Card Not Supported  iOS v14.0
# 653  Memory Card Not Supported    iOS v15
# 929  Memory Card Not Supported  iOS v14.0

# %% [markdown]
# **Cleaning Display Column**

# %%
df1[df1['index'].isin(display_rows)]
# Out:
#      index                            model   price  rating  \
# 85      87                  Apple iPhone 12   53900    74.0
# 117    119             Apple iPhone 12 Mini   40999    74.0
# 219    221          Apple iPhone 12 (128GB)   57900    75.0
# 266    268           Apple iPhone SE 3 2022   43900     NaN
# 360    362      Apple iPhone 12 Pro (512GB)  139900    80.0
# 506    508          Apple iPhone 12 (256GB)   67999    76.0
# 533    535   Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548     Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588      Apple iPhone 12 Pro (256GB)  119900    80.0
# 653    655   Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 929    931  Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                          sim  \
# 85   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 117  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 85     Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 117    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 219    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 266  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 360    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 506    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 533  Bionic  A15, Hexa Core, 3.22 GHz Processor            128 GB inbuilt
# 546    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 586    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 653  Bionic  A15, Hexa Core, 3.22 GHz Processor            256 GB inbuilt
# 929    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
#
#                                                battery  \
# 85   6.1 inches, 1170 x 2532 px Display with Large ...
# 117                 5.4 inches, 1080 x 2340 px Display
# 219  6.1 inches, 1170 x 2532 px Display with Large ...
# 266                                               None
# 360                                               None
# 506                                               None
# 533                                               None
# 546                                               None
# 586                                               None
# 653                                               None
# 929                                               None
#
#                                                display  \
# 85        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 117       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 219       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                  4.7 inches, 750 x 1334 px Display
# 360  6.1 inches, 1170 x 2532 px Display with Large ...
# 506  6.1 inches, 1170 x 2532 px Display with Large ...
# 533                  4.7 inches, 750 x 1334 px Display
# 546                 5.4 inches, 1080 x 2340 px Display
# 586  6.1 inches, 1170 x 2532 px Display with Large ...
# 653                  4.7 inches, 750 x 1334 px Display
# 929  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 camera  \
# 85                           Memory Card Not Supported
# 117                          Memory Card Not Supported
# 219                          Memory Card Not Supported
# 266                     12 MP Rear & 7 MP Front Camera
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 653                     12 MP Rear & 7 MP Front Camera
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card           os
# 85                     iOS v14  No FM Radio
# 117                    iOS v14  No FM Radio
# 219                    iOS v14  No FM Radio
# 266  Memory Card Not Supported      iOS v15
# 360  Memory Card Not Supported    iOS v14.0
# 506  Memory Card Not Supported      iOS v14
# 533  Memory Card Not Supported      iOS v15
# 546  Memory Card Not Supported      iOS v14
# 586  Memory Card Not Supported    iOS v14.0
# 653  Memory Card Not Supported      iOS v15
# 929  Memory Card Not Supported    iOS v14.0

# %%
# Shifting forward values by one position

temp_df = df1[df1['index'].isin([87,119,221])]
x = temp_df.iloc[:,7:].shift(1,axis=1).values
df1.loc[temp_df.index,temp_df.columns[7:]] = x
df1[df1['index'].isin(display_rows)]
# Out:
#      index                            model   price  rating  \
# 85      87                  Apple iPhone 12   53900    74.0
# 117    119             Apple iPhone 12 Mini   40999    74.0
# 219    221          Apple iPhone 12 (128GB)   57900    75.0
# 266    268           Apple iPhone SE 3 2022   43900     NaN
# 360    362      Apple iPhone 12 Pro (512GB)  139900    80.0
# 506    508          Apple iPhone 12 (256GB)   67999    76.0
# 533    535   Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548     Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588      Apple iPhone 12 Pro (256GB)  119900    80.0
# 653    655   Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 929    931  Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                          sim  \
# 85   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 117  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 85     Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 117    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 219    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 266  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 360    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 506    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 533  Bionic  A15, Hexa Core, 3.22 GHz Processor            128 GB inbuilt
# 546    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 586    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 653  Bionic  A15, Hexa Core, 3.22 GHz Processor            256 GB inbuilt
# 929    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
#
#     battery                                            display  \
# 85     None  6.1 inches, 1170 x 2532 px Display with Large ...
# 117    None                 5.4 inches, 1080 x 2340 px Display
# 219    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 266    None                  4.7 inches, 750 x 1334 px Display
# 360    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 506    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 533    None                  4.7 inches, 750 x 1334 px Display
# 546    None                 5.4 inches, 1080 x 2340 px Display
# 586    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 653    None                  4.7 inches, 750 x 1334 px Display
# 929    None  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 camera  \
# 85        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 117       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 219       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                     12 MP Rear & 7 MP Front Camera
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 653                     12 MP Rear & 7 MP Front Camera
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card         os
# 85   Memory Card Not Supported    iOS v14
# 117  Memory Card Not Supported    iOS v14
# 219  Memory Card Not Supported    iOS v14
# 266  Memory Card Not Supported    iOS v15
# 360  Memory Card Not Supported  iOS v14.0
# 506  Memory Card Not Supported    iOS v14
# 533  Memory Card Not Supported    iOS v15
# 546  Memory Card Not Supported    iOS v14
# 586  Memory Card Not Supported  iOS v14.0
# 653  Memory Card Not Supported    iOS v15
# 929  Memory Card Not Supported  iOS v14.0

# %% [markdown]
# **Cleaning Camera Column**

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#      index                                          model   price  rating  \
# 85      87                                Apple iPhone 12   53900    74.0
# 117    119                           Apple iPhone 12 Mini   40999    74.0
# 124    126                        Samsung Galaxy Z Flip 3   69999    84.0
# 219    221                        Apple iPhone 12 (128GB)   57900    75.0
# 242    244                        Samsung Galaxy Z Fold 4  146999     NaN
# 244    246                   Apple iPhone 12 Mini (128GB)   45999    75.0
# 266    268                         Apple iPhone SE 3 2022   43900     NaN
# 326    328                     Samsung Galaxy Z Flip 4 5G   82999    88.0
# 347    349                                     LG Wing 5G   54999    89.0
# 360    362                    Apple iPhone 12 Pro (512GB)  139900    80.0
# 438    440                        Samsung Galaxy Z Fold 3  110999    89.0
# 506    508                        Apple iPhone 12 (256GB)   67999    76.0
# 527    529       Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 533    535                 Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548                   Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588                    Apple iPhone 12 Pro (256GB)  119900    80.0
# 607    609     Samsung Galaxy Z Fold 4 (12GB RAM + 512GB)  156999     NaN
# 653    655                 Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 663    665   Samsung Galaxy Z Flip 3 5G (8GB RAM + 256GB)   83999    85.0
# 703    705      Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   94999    88.0
# 792    794  Samsung Galaxy Z Fold 3 5G (12GB RAM + 512GB)  101800    89.0
# 929    931                Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                            sim  \
# 85     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 117    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 124  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 242    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 244    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 326    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 347    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 438    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 527    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 607    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 663  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 792    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 85            Bionic A14, Hexa Core, 3.1 GHz Processor
# 117           Bionic A14, Hexa Core, 3.1 GHz Processor
# 124      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 219           Bionic A14, Hexa Core, 3.1 GHz Processor
# 242  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 244           Bionic A14, Hexa Core, 3.1 GHz Processor
# 266         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 326  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 347    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 360           Bionic A14, Hexa Core, 3.1 GHz Processor
# 438      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 506           Bionic A14, Hexa Core, 3.1 GHz Processor
# 527  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 533         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 546           Bionic A14, Hexa Core, 3.1 GHz Processor
# 586           Bionic A14, Hexa Core, 3.1 GHz Processor
# 607  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 653         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 663      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 703  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 792      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 929           Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                            ram                                  battery  \
# 85     4 GB RAM, 64 GB inbuilt                                     None
# 117    4 GB RAM, 64 GB inbuilt                                     None
# 124   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 219   4 GB RAM, 128 GB inbuilt                                     None
# 242  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 244   4 GB RAM, 128 GB inbuilt                                     None
# 266              64 GB inbuilt                                     None
# 326   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 347   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 360   6 GB RAM, 512 GB inbuilt                                     None
# 438  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 506   4 GB RAM, 256 GB inbuilt                                     None
# 527    12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 533             128 GB inbuilt                                     None
# 546   4 GB RAM, 256 GB inbuilt                                     None
# 586   6 GB RAM, 256 GB inbuilt                                     None
# 607  12 GB RAM, 512 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 653             256 GB inbuilt                                     None
# 663   8 GB RAM, 256 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 703   8 GB RAM, 256 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 792  12 GB RAM, 512 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 929   6 GB RAM, 512 GB inbuilt                                     None
#
#                                                display  \
# 85   6.1 inches, 1170 x 2532 px Display with Large ...
# 117                 5.4 inches, 1080 x 2340 px Display
# 124  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 219  6.1 inches, 1170 x 2532 px Display with Large ...
# 242  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 244                 5.4 inches, 1080 x 2340 px Display
# 266                  4.7 inches, 750 x 1334 px Display
# 326  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 347                 6.8 inches, 1080 x 2460 px Display
# 360  6.1 inches, 1170 x 2532 px Display with Large ...
# 438  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 506  6.1 inches, 1170 x 2532 px Display with Large ...
# 527  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 533                  4.7 inches, 750 x 1334 px Display
# 546                 5.4 inches, 1080 x 2340 px Display
# 586  6.1 inches, 1170 x 2532 px Display with Large ...
# 607  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 653                  4.7 inches, 750 x 1334 px Display
# 663  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 703  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 792  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 929  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 camera  \
# 85        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 117       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 124                     Foldable Display, Dual Display
# 219       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 242                     Foldable Display, Dual Display
# 244       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                     12 MP Rear & 7 MP Front Camera
# 326                     Foldable Display, Dual Display
# 347                                       Dual Display
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 438                     Foldable Display, Dual Display
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 527                     Foldable Display, Dual Display
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607                     Foldable Display, Dual Display
# 653                     12 MP Rear & 7 MP Front Camera
# 663                     Foldable Display, Dual Display
# 703                     Foldable Display, Dual Display
# 792                     Foldable Display, Dual Display
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                                                   card  \
# 85                           Memory Card Not Supported
# 117                          Memory Card Not Supported
# 124       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 219                          Memory Card Not Supported
# 242  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 244                          Memory Card Not Supported
# 266                          Memory Card Not Supported
# 326       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 347  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 360                          Memory Card Not Supported
# 438  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 506                          Memory Card Not Supported
# 527  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 533                          Memory Card Not Supported
# 546                          Memory Card Not Supported
# 586                          Memory Card Not Supported
# 607  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 653                          Memory Card Not Supported
# 663       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 703       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 792  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 929                          Memory Card Not Supported
#
#                                   os
# 85                           iOS v14
# 117                          iOS v14
# 124        Memory Card Not Supported
# 219                          iOS v14
# 242                      Android v12
# 244                          iOS v14
# 266                          iOS v15
# 326        Memory Card Not Supported
# 347  Memory Card (Hybrid), upto 2 TB
# 360                        iOS v14.0
# 438                      Android v11
# 506                          iOS v14
# 527                      Android v12
# 533                          iOS v15
# 546                          iOS v14
# 586                        iOS v14.0
# 607                      Android v12
# 653                          iOS v15
# 663        Memory Card Not Supported
# 703        Memory Card Not Supported
# 792                      Android v11
# 929                        iOS v14.0

# %%
temp_df = df1[df1['index'].isin(camera_rows)]
temp_df = temp_df[~temp_df['camera'].str.contains('MP')]
df1.loc[temp_df.index, 'camera'] = temp_df['card'].values

# %%
df1[df1['index'].isin(camera_rows)]
# Out:
#      index                                          model   price  rating  \
# 85      87                                Apple iPhone 12   53900    74.0
# 117    119                           Apple iPhone 12 Mini   40999    74.0
# 124    126                        Samsung Galaxy Z Flip 3   69999    84.0
# 219    221                        Apple iPhone 12 (128GB)   57900    75.0
# 242    244                        Samsung Galaxy Z Fold 4  146999     NaN
# 244    246                   Apple iPhone 12 Mini (128GB)   45999    75.0
# 266    268                         Apple iPhone SE 3 2022   43900     NaN
# 326    328                     Samsung Galaxy Z Flip 4 5G   82999    88.0
# 347    349                                     LG Wing 5G   54999    89.0
# 360    362                    Apple iPhone 12 Pro (512GB)  139900    80.0
# 438    440                        Samsung Galaxy Z Fold 3  110999    89.0
# 506    508                        Apple iPhone 12 (256GB)   67999    76.0
# 527    529       Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980     NaN
# 533    535                 Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 546    548                   Apple iPhone 12 Mini (256GB)   55999    75.0
# 586    588                    Apple iPhone 12 Pro (256GB)  119900    80.0
# 607    609     Samsung Galaxy Z Fold 4 (12GB RAM + 512GB)  156999     NaN
# 653    655                 Apple iPhone SE 3 2022 (256GB)   58900    61.0
# 663    665   Samsung Galaxy Z Flip 3 5G (8GB RAM + 256GB)   83999    85.0
# 703    705      Samsung Galaxy Z Flip 4 (8GB RAM + 256GB)   94999    88.0
# 792    794  Samsung Galaxy Z Fold 3 5G (12GB RAM + 512GB)  101800    89.0
# 929    931                Apple iPhone 12 Pro Max (512GB)  149900    81.0
#
#                                            sim  \
# 85     Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 117    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 124  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 219    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 242    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 244    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 266    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 326    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 347    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 360    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 438    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 506    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 527    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 533    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 546    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 586    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 607    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 653    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 663  Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 703    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 792    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 929    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 85            Bionic A14, Hexa Core, 3.1 GHz Processor
# 117           Bionic A14, Hexa Core, 3.1 GHz Processor
# 124      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 219           Bionic A14, Hexa Core, 3.1 GHz Processor
# 242  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 244           Bionic A14, Hexa Core, 3.1 GHz Processor
# 266         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 326  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 347    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 360           Bionic A14, Hexa Core, 3.1 GHz Processor
# 438      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 506           Bionic A14, Hexa Core, 3.1 GHz Processor
# 527  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 533         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 546           Bionic A14, Hexa Core, 3.1 GHz Processor
# 586           Bionic A14, Hexa Core, 3.1 GHz Processor
# 607  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 653         Bionic  A15, Hexa Core, 3.22 GHz Processor
# 663      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 703  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 792      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 929           Bionic A14, Hexa Core, 3.1 GHz Processor
#
#                            ram                                  battery  \
# 85     4 GB RAM, 64 GB inbuilt                                     None
# 117    4 GB RAM, 64 GB inbuilt                                     None
# 124   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 219   4 GB RAM, 128 GB inbuilt                                     None
# 242  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 244   4 GB RAM, 128 GB inbuilt                                     None
# 266              64 GB inbuilt                                     None
# 326   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 347   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 360   6 GB RAM, 512 GB inbuilt                                     None
# 438  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 506   4 GB RAM, 256 GB inbuilt                                     None
# 527    12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 533             128 GB inbuilt                                     None
# 546   4 GB RAM, 256 GB inbuilt                                     None
# 586   6 GB RAM, 256 GB inbuilt                                     None
# 607  12 GB RAM, 512 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 653             256 GB inbuilt                                     None
# 663   8 GB RAM, 256 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 703   8 GB RAM, 256 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 792  12 GB RAM, 512 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 929   6 GB RAM, 512 GB inbuilt                                     None
#
#                                                display  \
# 85   6.1 inches, 1170 x 2532 px Display with Large ...
# 117                 5.4 inches, 1080 x 2340 px Display
# 124  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 219  6.1 inches, 1170 x 2532 px Display with Large ...
# 242  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 244                 5.4 inches, 1080 x 2340 px Display
# 266                  4.7 inches, 750 x 1334 px Display
# 326  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 347                 6.8 inches, 1080 x 2460 px Display
# 360  6.1 inches, 1170 x 2532 px Display with Large ...
# 438  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 506  6.1 inches, 1170 x 2532 px Display with Large ...
# 527  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 533                  4.7 inches, 750 x 1334 px Display
# 546                 5.4 inches, 1080 x 2340 px Display
# 586  6.1 inches, 1170 x 2532 px Display with Large ...
# 607  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 653                  4.7 inches, 750 x 1334 px Display
# 663  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 703  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 792  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 929  6.7 inches, 1284 x 2778 px Display with Large ...
#
#                                                 camera  \
# 85        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 117       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 124       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 219       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 242  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 244       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 266                     12 MP Rear & 7 MP Front Camera
# 326       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 347  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 360  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 438  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 506       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 527  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 533                     12 MP Rear & 7 MP Front Camera
# 546       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 586  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 607  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 653                     12 MP Rear & 7 MP Front Camera
# 663       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 703       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 792  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 929  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                                                   card  \
# 85                           Memory Card Not Supported
# 117                          Memory Card Not Supported
# 124       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 219                          Memory Card Not Supported
# 242  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 244                          Memory Card Not Supported
# 266                          Memory Card Not Supported
# 326       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 347  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 360                          Memory Card Not Supported
# 438  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 506                          Memory Card Not Supported
# 527  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 533                          Memory Card Not Supported
# 546                          Memory Card Not Supported
# 586                          Memory Card Not Supported
# 607  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 653                          Memory Card Not Supported
# 663       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 703       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 792  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 929                          Memory Card Not Supported
#
#                                   os
# 85                           iOS v14
# 117                          iOS v14
# 124        Memory Card Not Supported
# 219                          iOS v14
# 242                      Android v12
# 244                          iOS v14
# 266                          iOS v15
# 326        Memory Card Not Supported
# 347  Memory Card (Hybrid), upto 2 TB
# 360                        iOS v14.0
# 438                      Android v11
# 506                          iOS v14
# 527                      Android v12
# 533                          iOS v15
# 546                          iOS v14
# 586                        iOS v14.0
# 607                      Android v12
# 653                          iOS v15
# 663        Memory Card Not Supported
# 703        Memory Card Not Supported
# 792                      Android v11
# 929                        iOS v14.0

# %% [markdown]
# **Cleaning Card Columns**

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 256 GB                                    162
# Memory Card Supported, upto 1 TB                                      147
# Memory Card Supported, upto 512 GB                                    124
# Memory Card Not Supported                                              85
# Memory Card (Hybrid), upto 1 TB                                        68
# Android v12                                                            66
# Memory Card Supported                                                  55
# Android v11                                                            28
# Memory Card (Hybrid)                                                   22
# Memory Card Supported, upto 128 GB                                     21
# Memory Card (Hybrid), upto 256 GB                                      16
# Memory Card (Hybrid), upto 512 GB                                      15
# Android v10                                                            13
# Memory Card (Hybrid), upto 128 GB                                      11
# Memory Card Supported, upto 2 TB                                        9
# Memory Card (Hybrid), upto 64 GB                                        6
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                            4
# Android v13                                                             4
# Memory Card Supported, upto 32 GB                                       4
# Memory Card Supported, upto 64 GB                                       4
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera      3
# iOS v13                                                                 3
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera      2
# Android v9.0 (Pie)                                                      2
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                  1
# Android v10.0                                                           1
# Memory Card (Hybrid), upto 400 GB                                       1
# Android v6.0 (Marshmallow)                                              1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['card'].str.contains('MP')]
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Supported, upto 256 GB    162
# Memory Card Supported, upto 1 TB      147
# Memory Card Supported, upto 512 GB    124
# Memory Card Not Supported              95
# Memory Card (Hybrid), upto 1 TB        68
# Android v12                            66
# Memory Card Supported                  55
# Android v11                            28
# Memory Card (Hybrid)                   22
# Memory Card Supported, upto 128 GB     21
# Memory Card (Hybrid), upto 256 GB      16
# Memory Card (Hybrid), upto 512 GB      15
# Android v10                            13
# Memory Card (Hybrid), upto 128 GB      11
# Memory Card Supported, upto 2 TB        9
# Memory Card (Hybrid), upto 64 GB        6
# Android v13                             4
# Memory Card Supported, upto 32 GB       4
# Memory Card Supported, upto 64 GB       4
# iOS v13                                 3
# Android v9.0 (Pie)                      2
# Android v10.0                           1
# Memory Card (Hybrid), upto 400 GB       1
# Android v6.0 (Marshmallow)              1
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning OS columns**

# %%
temp_df = df1[~df1['card'].str.contains('Memory Card')]
df1.loc[temp_df.index,'os'] = temp_df['card'].values

# %%
df1.loc[temp_df.index,'card'] = 'Memory Card Not Supported'

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             213
# Memory Card Supported, upto 256 GB    162
# Memory Card Supported, upto 1 TB      147
# Memory Card Supported, upto 512 GB    124
# Memory Card (Hybrid), upto 1 TB        68
# Memory Card Supported                  55
# Memory Card (Hybrid)                   22
# Memory Card Supported, upto 128 GB     21
# Memory Card (Hybrid), upto 256 GB      16
# Memory Card (Hybrid), upto 512 GB      15
# Memory Card (Hybrid), upto 128 GB      11
# Memory Card Supported, upto 2 TB        9
# Memory Card (Hybrid), upto 64 GB        6
# Memory Card Supported, upto 32 GB       4
# Memory Card Supported, upto 64 GB       4
# Memory Card (Hybrid), upto 400 GB       1
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# Android v11                        277
# Android v12                        248
# Android v10                        119
# Android v9.0 (Pie)                  52
# Android v10.0                       37
# Android v8.1 (Oreo)                 27
# iOS v16                             14
# iOS v15                             13
# Android v13                         12
# Android v8.0 (Oreo)                 11
# iOS v13                              7
# Android v6.0 (Marshmallow)           7
# iOS v14                              6
# Android v5.1 (Lollipop)              6
# Android v11.0                        5
# Memory Card Not Supported            4
# iOS v15.0                            4
# Android v9 (Pie)                     4
# iOS v14.0                            3
# Android v6.0.1 (Marshmallow)         3
# Android                              2
# Android v7.1.2 (Nougat)              2
# Android v5.1.1 (Lollipop)            2
# Android v7.0 (Nougat)                2
# Android v7.1 (Nougat)                2
# Android v7.1.1 (Nougat)              1
# Android v11.1                        1
# Android v9.1 (Pie)                   1
# Memory Card (Hybrid), upto 2 TB      1
# Blackberry OS v10.3                  1
# iOS v10.0.1                          1
# RTOS (Series 30+)                    1
# Hongmeng OS v3.0                     1
# Android v4.4.2 (KitKat)              1
# Name: count, dtype: int64

# %%
temp_df = df1[df1['os'].str.contains('Memory Card')]
df1.loc[temp_df.index,'os'] = np.nan

# %%
df1.head()
# Out:
#    index                                    model  price  rating  \
# 0      2                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3                    Samsung Galaxy A14 5G  16499    75.0
# 2      4  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5                     Motorola Moto G62 5G  14999    81.0
# 4      6                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 878 entries, 0 to 992
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      878 non-null    int64
#  1   model      878 non-null    object
#  2   price      878 non-null    int64
#  3   rating     792 non-null    float64
#  4   sim        878 non-null    object
#  5   processor  878 non-null    object
#  6   ram        878 non-null    object
#  7   battery    866 non-null    object
#  8   display    878 non-null    object
#  9   camera     878 non-null    object
#  10  card       878 non-null    object
#  11  os         873 non-null    object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 121.5+ KB

# %% [markdown]
# **Percentage of data removed**

# %%
(878/1020)*100
# Out:
# 86.07843137254902

# %% [markdown]
# **About 14% of data removed**

# %% [markdown]
# **Extracting Brand Names from model column**

# %%
brand_names = df1['model'].str.split(' ').str.get(0)
df1.insert(1,'brand_name',brand_names)
df1['brand_name'] = df1['brand_name'].str.lower()

# %%
df1.head()
# Out:
#    index brand_name                                    model  price  rating  \
# 0      2    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3    samsung                    Samsung Galaxy A14 5G  16499    75.0
# 2      4    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5   motorola                     Motorola Moto G62 5G  14999    81.0
# 4      6     realme                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **Extracting Features 5G,NFC,IR Blaster**

# %%
has_5g = df1['sim'].str.contains('5G')
has_nfc = df1['sim'].str.contains('NFC')
has_ir_blaster = df1['sim'].str.contains('IR Blaster')

# %%
df1.insert(6,'has_5g',has_5g)
df1.insert(7,'has_nfc',has_nfc)
df1.insert(8,'has_ir_blaster',has_ir_blaster)

# %%
df1.head()
# Out:
#    index brand_name                                    model  price  rating  \
# 0      2    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3    samsung                    Samsung Galaxy A14 5G  16499    75.0
# 2      4    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5   motorola                     Motorola Moto G62 5G  14999    81.0
# 4      6     realme                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                         processor                       ram  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **Extracting Processor Name,Processor Speed and number of Cores**

# %%
processor_name = df1['processor'].str.split(',').str.get(0)
num_cores = df1['processor'].str.split(',').str.get(1)
processor_speed = df1['processor'].str.split(',').str.get(2)

# %%
df1.insert(10,'processor_name',processor_name)
df1.insert(11,'num_cores',num_cores)
df1.insert(12,'processor_speed',processor_speed)

# %%
df1['processor_name'] = df1['processor_name'].str.strip()

# %%
df1['num_cores'] = df1['num_cores'].str.strip()

# %%
df1.head()
# Out:
#    index brand_name                                    model  price  rating  \
# 0      2    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3    samsung                    Samsung Galaxy A14 5G  16499    75.0
# 2      4    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5   motorola                     Motorola Moto G62 5G  14999    81.0
# 4      6     realme                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                         processor    processor_name  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor    Snapdragon 695
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor       Exynos 1330
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  Snapdragon  750G
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor   Snapdragon  695
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor    Dimensity 1080
#
#     num_cores     processor_speed                       ram  \
# 0   Octa Core   2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 1   Octa Core   2.4 GHz Processor   4 GB RAM, 64 GB inbuilt
# 2   Octa Core   2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 3   Octa Core   2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 4   Octa Core   2.6 GHz Processor  6 GB RAM, 128 GB inbuilt
#
#                                    battery  \
# 0  5000 mAh Battery with 33W Fast Charging
# 1  5000 mAh Battery with 15W Fast Charging
# 2  5000 mAh Battery with 25W Fast Charging
# 3      5000 mAh Battery with Fast Charging
# 4  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **Cleaning Processor Name Columns**

# %%
df1['processor_name'].value_counts()
# Out:
# processor_name
# Helio P35                  30
# Helio G35                  28
# Snapdragon 680             21
# Quad Core                  20
# Bionic A15                 20
# Helio G80                  20
# Helio G95                  16
# Snapdragon  680            16
# Snapdragon  695            15
# Dimensity 700 5G           15
# Snapdragon 695             13
# Helio P22                  13
# Dimensity  810 5G          13
# Helio G88                  12
# Helio G96                  12
# Snapdragon 720G            12
# Helio A22                  12
# Unisoc  SC9863A            12
# Helio G85                  12
# Snapdragon 870             11
# Helio G37                  11
# Helio G25                  11
# Snapdragon 662             10
# Dimensity  920 5G          10
# Helio G70                  10
# Snapdragon  778G           10
# Dimensity 810 5G            9
# Snapdragon 8 Gen1           9
# Bionic A14                  9
# Snapdragon  8 Gen1          9
# Snapdragon  888             9
# Snapdragon 888              8
# Helio G99                   8
# Dimensity 1080              8
# Bionic  A16                 8
# Tiger T612                  8
# Helio  G85                  7
# A13 Bionic                  7
# Exynos 850                  7
# Snapdragon 665              7
# Octa Core                   7
# Snapdragon  439             7
# Snapdragon  8+ Gen1         7
# Snapdragon 675              7
# Snapdragon  732G            7
# Snapdragon 865              6
# Snapdragon 8+ Gen1          6
# Dimensity 1200              6
# Snapdragon  720G            6
# Unisoc  T606                6
# Dimensity  8100             6
# Helio                       5
# Snapdragon 450              5
# Snapdragon  888+            5
# Helio  G96                  5
# Snapdragon  662             5
# Dimensity 700               5
# Exynos  2100                5
# Dimensity 800U              5
# Snapdragon 439              4
# Helio A25                   4
# Snapdragon 778G             4
# Snapdragon 845              4
# Dimensity 900               4
# Snapdragon 425              4
# Helio A20                   4
# Exynos  850                 4
# Qualcomm Snapdragon 660     4
# Snapdragon  730G            4
# Snapdragon 460              4
# Helio  G25                  4
# Exynos  1280                4
# Snapdragon 855+             4
# Snapdragon 732G             4
# Tiger  T616                 3
# Snapdragon  665             3
# Snapdragon  750G            3
# Exynos 1330                 3
# Exynos 9810                 3
# Tiger  T610                 3
# Bionic  A15                 3
# Helio P95                   3
# Snapdragon 712              3
# Snapdragon  870             3
# Helio  G35                  3
# SC9863A                     3
# Snapdragon 636              3
# Exynos 1280                 3
# Snapdragon 835              3
# Snapdragon 778G Plus        3
# Google  Tensor              3
# Snapdragon  450             3
# Dimensity 1300              3
# Dimensity 8100 Max          3
# Helio  P22                  2
# Unisoc T610                 2
# Exynos 9611                 2
# Dimensity  900 5G           2
# Dimensity 1000+             2
# Helio   G90T                2
# Exynos 2100                 2
# Snapdragon  712             2
# Snapdragon MSM8939          2
# Exynos 9610                 2
# Spreadtrum  SC9832E         2
# Exynos  7904                2
# Kirin 659                   2
# Unisoc  SC9863a             2
# Helio  G95                  2
# Snapdragon 660              2
# Snapdragon 625              2
# Snapdragon 626              2
# Quad Core Processor         2
# Helio  P60                  2
# Snapdragon  865             2
# Snapdragon 678              2
# Helio  G99                  2
# Unisoc SC9863A              2
# Snapdragon 4 Gen 1          2
# Snapdragon 765G             2
# Dimensity 9000              2
# Snapdragon 8 Gen2           2
# Snapdragon 778G+            2
# Dimensity 920 5G            2
# Snapdragon  4 Gen 1         2
# Dimensity  900              2
# Dimensity  1300             2
# Exynos 990                  2
# Unisoc T612                 2
# Dimensity 810               2
# Exynos  990                 2
# Unisoc  T610                2
# Dimensity  9000             2
# Snapdragon 860              2
# Tiger T610                  2
# Tiger T616                  2
# Snapdragon 730              2
# Tiger T700                  1
# Helio MT6739WW              1
# Spreadtrum 9863A            1
# Exynos 7580                 1
# Exynos 9609                 1
# Helio G90T                  1
# Snapdragon 801              1
# Snapdragon 616              1
# UNISOC SC9863               1
# Snapdragon 652              1
# Helio MT6750                1
# Helio P70 (12nm)            1
# Helio P90                   1
# Snapdragon 710              1
# Snapdragon 410              1
# Exynos 7570                 1
# Snapdragon MSM8909          1
# Snapdragon 821              1
# Snapdragon MSM8952          1
# Spreadtrum  SC9863A         1
# MT 6739W                    1
# Snapdragon  460             1
# Helio MT6737                1
# Snapdragon MSM8917          1
# Exynos 7870                 1
# Snapdragon 430              1
# Helio MTK6757V              1
# Unisoc T117                 1
# Sprd  9832e                 1
# Dimensity  700 5G           1
# Snapdragon 855              1
# Qualcomm Snapdragon 670     1
# Google Tensor               1
# Helio  G90T                 1
# Exynos 9820                 1
# Helio  P65                  1
# Qualcomm 215                1
# Exynos  9611                1
# Snapdragon 888+             1
# Helio  G37                  1
# Snapdragon 615              1
# Unisoc T606                 1
# Snapdragon 730G             1
# Qualcomm Snapdragon 625     1
# Snapdragon  765G            1
# Exynos 7885                 1
# Unisoc  SC9836A             1
# Helio P20                   1
# Dimensity 720               1
# Snapdragon  480+            1
# Helio P70                   1
# Dimensity  1200 Max         1
# Google Tensor G2            1
# Fusion A10                  1
# Helio  G88                  1
# Dimensity 8100-Max          1
# Unisoc  A55                 1
# Qualcomm Snapdragon 632     1
# Qualcomm Snapdragon 425     1
# Helio P60                   1
# Google  Tensor G2           1
# Snapdragon  480             1
# Kirin 920                   1
# Name: count, dtype: int64

# %%
df1[df1['processor_name'].str.contains('Core')]
# Out:
#      index brand_name                                 model  price  rating  \
# 132    134    samsung                    Samsung Galaxy A13  14450    75.0
# 160    162      ikall                         iKall Z19 Pro   7999    60.0
# 237    239    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  15499    75.0
# 430    432    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499    78.0
# 523    525      ikall                             iKall Z19   7999    61.0
# 614    616      tecno                   Tecno Spark Go 2022   6249    61.0
# 642    644      ikall                             iKall Z18   6799    61.0
# 701    703      ikall                             iKall Z15   6799    61.0
# 763    765      ikall                        iKall K350 New   4999     NaN
# 766    768      ikall                             iKall Z13   6399    61.0
# 769    771      ikall                        iKall K401 Pro   6199    60.0
# 771    773      ikall                             iKall Z14   6799    61.0
# 773    775      ikall                        iKall K401 New   6283    60.0
# 799    801      tecno                   Tecno Spark Go 2021   8998    61.0
# 818    820       itel                              itel A48   5540     NaN
# 828    830       lava                          Lava Z61 Pro   5099     NaN
# 856    858   micromax        Micromax Canvas Xpress 4G Q413   4999     NaN
# 864    866      ikall                             iKall Z17   6649    61.0
# 874    876      ikall                        iKall K470 New   5949     NaN
# 875    877      ikall                             iKall Z12   7299     NaN
# 881    883      ikall                        iKall K475 New   6999     NaN
# 882    884      ikall                              iKall Z9   4999     NaN
# 883    885      ikall                         iKall Z10 New   6699    62.0
# 884    886      ikall                        iKall K570 New   7999    61.0
# 885    887      ikall                          iKall Z6 Pro   6949    60.0
# 945    947      ikall                         iKall K2 Plus   5699     NaN
# 955    957      ikall                            iKall K200   4299     NaN
# 976    978      ikall                              iKall K2   3989     NaN
# 985    987      swipe                     Swipe Elite Sense   4100     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 132  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 160  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 237  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 430  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 523  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 614  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 642  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 701  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 763  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 766  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 769  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 771  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 773  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 799  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 818      Dual Sim, 3G, VoLTE, Wi-Fi   False    False           False
# 828  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 856         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 864  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 874  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 875         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 881  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 882  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 883  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 884  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 885  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 945         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 955  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 976  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
# 985  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                         processor       processor_name           num_cores  \
# 132    Octa Core, 2 GHz Processor            Octa Core     2 GHz Processor
# 160  Quad Core, 1.6 GHz Processor            Quad Core   1.6 GHz Processor
# 237    Octa Core, 2 GHz Processor            Octa Core     2 GHz Processor
# 430    Octa Core, 2 GHz Processor            Octa Core     2 GHz Processor
# 523  Quad Core, 1.6 GHz Processor            Quad Core   1.6 GHz Processor
# 614  Octa Core, 2.2 GHz Processor            Octa Core   2.2 GHz Processor
# 642  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 701  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 763  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 766  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 769  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 771  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 773  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 799  Octa Core, 1.8 GHz Processor            Octa Core   1.8 GHz Processor
# 818           Quad Core Processor  Quad Core Processor                 NaN
# 828  Octa Core, 1.6 GHz Processor            Octa Core   1.6 GHz Processor
# 856    Quad Core, 1 GHz Processor            Quad Core     1 GHz Processor
# 864  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 874  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 875  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 881  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 882  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 883  Quad Core, 1.6 GHz Processor            Quad Core   1.6 GHz Processor
# 884  Octa Core, 1.6 GHz Processor            Octa Core   1.6 GHz Processor
# 885  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 945  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 955  Quad Core, 1.3 GHz Processor            Quad Core   1.3 GHz Processor
# 976           Quad Core Processor  Quad Core Processor                 NaN
# 985  Quad Core, 1.4 GHz Processor            Quad Core   1.4 GHz Processor
#
#     processor_speed                       ram  \
# 132             NaN   4 GB RAM, 64 GB inbuilt
# 160             NaN   4 GB RAM, 64 GB inbuilt
# 237             NaN  4 GB RAM, 128 GB inbuilt
# 430             NaN  6 GB RAM, 128 GB inbuilt
# 523             NaN   4 GB RAM, 32 GB inbuilt
# 614             NaN   2 GB RAM, 32 GB inbuilt
# 642             NaN   4 GB RAM, 64 GB inbuilt
# 701             NaN   4 GB RAM, 64 GB inbuilt
# 763             NaN   3 GB RAM, 32 GB inbuilt
# 766             NaN   4 GB RAM, 64 GB inbuilt
# 769             NaN   4 GB RAM, 64 GB inbuilt
# 771             NaN   4 GB RAM, 64 GB inbuilt
# 773             NaN   4 GB RAM, 64 GB inbuilt
# 799             NaN   2 GB RAM, 32 GB inbuilt
# 818             NaN   2 GB RAM, 32 GB inbuilt
# 828             NaN   2 GB RAM, 16 GB inbuilt
# 856             NaN   2 GB RAM, 16 GB inbuilt
# 864             NaN   4 GB RAM, 64 GB inbuilt
# 874             NaN   4 GB RAM, 32 GB inbuilt
# 875             NaN   4 GB RAM, 64 GB inbuilt
# 881             NaN   4 GB RAM, 64 GB inbuilt
# 882             NaN   3 GB RAM, 32 GB inbuilt
# 883             NaN   4 GB RAM, 64 GB inbuilt
# 884             NaN   4 GB RAM, 64 GB inbuilt
# 885             NaN   4 GB RAM, 64 GB inbuilt
# 945             NaN   4 GB RAM, 64 GB inbuilt
# 955             NaN   2 GB RAM, 16 GB inbuilt
# 976             NaN    1 GB RAM, 8 GB inbuilt
# 985             NaN   3 GB RAM, 32 GB inbuilt
#
#                                      battery  \
# 132  5000 mAh Battery with 25W Fast Charging
# 160                         5000 mAh Battery
# 237  5000 mAh Battery with 25W Fast Charging
# 430  5000 mAh Battery with 25W Fast Charging
# 523                         5000 mAh Battery
# 614                         5000 mAh Battery
# 642                         5000 mAh Battery
# 701                         5000 mAh Battery
# 763                         4000 mAh Battery
# 766                         5000 mAh Battery
# 769                         4000 mAh Battery
# 771                         5000 mAh Battery
# 773                         4000 mAh Battery
# 799                         5000 mAh Battery
# 818                         3000 mAh Battery
# 828                         3100 mAh Battery
# 856                         2000 mAh Battery
# 864                         5000 mAh Battery
# 874                         4000 mAh Battery
# 875      5000 mAh Battery with Fast Charging
# 881                         4000 mAh Battery
# 882                         4000 mAh Battery
# 883                         5000 mAh Battery
# 884                         5000 mAh Battery
# 885                         4000 mAh Battery
# 945                         3000 mAh Battery
# 955                         2500 mAh Battery
# 976                         2200 mAh Battery
# 985                         2500 mAh Battery
#
#                                                display  \
# 132  6.6 inches, 1080 x 2408 px Display with Water ...
# 160  6.5 inches, 720 x 1600 px Display with Water D...
# 237  6.6 inches, 1080 x 2408 px Display with Water ...
# 430  6.6 inches, 1080 x 2408 px Display with Water ...
# 523  6.5 inches, 720 x 1600 px Display with Water D...
# 614  6.51 inches, 720 x 1600 px Display with Water ...
# 642  6.82 inches, 720 x 1560 px Display with Punch ...
# 701  6.82 inches, 720 x 1600 px Display with Punch ...
# 763                     6 inches, 480 x 960 px Display
# 766  6.53 inches, 720 x 1520 px Display with Punch ...
# 769  6.26 inches, 720 x 1520 px Display with Water ...
# 771  6.82 inches, 720 x 1600 px Display with Punch ...
# 773  6.26 inches, 720 x 1520 px Display with Water ...
# 799  6.52 inches, 720 x 1600 px Display with Water ...
# 818  6.1 inches, 720 x 1520 px Display with Water D...
# 828                 5.45 inches, 720 x 1440 px Display
# 856                    5 inches, 720 x 1280 px Display
# 864  6.82 inches, 720 x 1600 px Display with Punch ...
# 874  6.26 inches, 720 x 1520 px Display with Water ...
# 875  6.53 inches, 720 x 1520 px Display with Water ...
# 881  6.26 inches, 720 x 1520 px Display with Water ...
# 882  5.99 inches, 720 x 1520 px Display with Water ...
# 883                 6.53 inches, 720 x 1600 px Display
# 884  6.53 inches, 480 x 960 px Display with Water D...
# 885                 6.26 inches, 1520 x 720 px Display
# 945                  5.5 inches, 720 x 1560 px Display
# 955                   5.5 inches, 480 x 960 px Display
# 976                     5 inches, 854 x 480 px Display
# 985                    5 inches, 1280 x 720 px Display
#
#                                          camera  \
# 132         50 MP Quad Rear & 8 MP Front Camera
# 160              13 MP Rear & 8 MP Front Camera
# 237         50 MP Quad Rear & 8 MP Front Camera
# 430         50 MP Quad Rear & 8 MP Front Camera
# 523             20 MP Rear & 13 MP Front Camera
# 614  13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 642             20 MP Rear & 13 MP Front Camera
# 701             20 MP Rear & 13 MP Front Camera
# 763               8 MP Rear & 5 MP Front Camera
# 766             20 MP Rear & 13 MP Front Camera
# 769             16 MP Rear & 13 MP Front Camera
# 771             20 MP Rear & 13 MP Front Camera
# 773             16 MP Rear & 13 MP Front Camera
# 799  13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 818               5 MP Rear & 5 MP Front Camera
# 828               8 MP Rear & 5 MP Front Camera
# 856               8 MP Rear & 2 MP Front Camera
# 864             20 MP Rear & 13 MP Front Camera
# 874             16 MP Rear & 13 MP Front Camera
# 875             20 MP Rear & 13 MP Front Camera
# 881             13 MP Rear & 16 MP Front Camera
# 882               8 MP Rear & 5 MP Front Camera
# 883             20 MP Rear & 13 MP Front Camera
# 884             20 MP Rear & 13 MP Front Camera
# 885             16 MP Rear & 13 MP Front Camera
# 945               8 MP Rear & 5 MP Front Camera
# 955               5 MP Rear & 2 MP Front Camera
# 976                            5 MP Rear Camera
# 985              13 MP Rear & 8 MP Front Camera
#
#                                    card                            os
# 132    Memory Card Supported, upto 1 TB                   Android v12
# 160   Memory Card (Hybrid), upto 128 GB                 Android v11.0
# 237    Memory Card Supported, upto 1 TB                   Android v12
# 430    Memory Card Supported, upto 1 TB                   Android v12
# 523   Memory Card (Hybrid), upto 128 GB                 Android v11.0
# 614  Memory Card Supported, upto 256 GB                   Android v11
# 642    Memory Card (Hybrid), upto 64 GB                 Android v10.0
# 701   Memory Card (Hybrid), upto 128 GB                 Android v10.0
# 763   Memory Card Supported, upto 64 GB                   Android v10
# 766    Memory Card (Hybrid), upto 64 GB                 Android v10.0
# 769               Memory Card Supported                   Android v10
# 771   Memory Card (Hybrid), upto 128 GB                 Android v10.0
# 773               Memory Card Supported                   Android v10
# 799  Memory Card Supported, upto 256 GB                   Android v10
# 818               Memory Card Supported                 Android v10.0
# 828  Memory Card Supported, upto 128 GB              Android v9 (Pie)
# 856   Memory Card Supported, upto 32 GB       Android v5.1 (Lollipop)
# 864   Memory Card (Hybrid), upto 128 GB                 Android v10.0
# 874  Memory Card Supported, upto 128 GB                   Android v10
# 875   Memory Card (Hybrid), upto 128 GB                   Android v10
# 881               Memory Card Supported                   Android v10
# 882  Memory Card Supported, upto 128 GB                   Android v10
# 883    Memory Card (Hybrid), upto 64 GB                 Android v10.0
# 884  Memory Card Supported, upto 256 GB                   Android v10
# 885   Memory Card Supported, upto 64 GB                 Android v10.0
# 945   Memory Card Supported, upto 64 GB                       Android
# 955                Memory Card (Hybrid)    Android v6.0 (Marshmallow)
# 976           Memory Card Not Supported    Android v6.0 (Marshmallow)
# 985    Memory Card (Hybrid), upto 64 GB  Android v6.0.1 (Marshmallow)

# %%
temp_df = df1[df1['processor_name'].str.contains('Core')][['processor_name', 'num_cores',	'processor_speed']].shift(1,axis=1)
df1.loc[temp_df.index,['processor_name', 'num_cores',	'processor_speed']] = temp_df.values

# %%
df1[df1['processor_name'] == 'Core']
# Out:
# Empty DataFrame
# Columns: [index, brand_name, model, price, rating, sim, has_5g, has_nfc, has_ir_blaster, processor, processor_name, num_cores, processor_speed, ram, battery, display, camera, card, os]
# Index: []

# %%
df1[df1['processor_name'] == 'MT 6739W']
# Out:
#      index brand_name               model  price  rating  \
# 930    932    samsung  Samsung Galaxy M02   8499     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 930  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                   processor processor_name   num_cores  \
# 930  MT 6739W, Quad Core, 1.5 GHz Processor       MT 6739W   Quad Core
#
#         processor_speed                      ram           battery  \
# 930   1.5 GHz Processor  2 GB RAM, 32 GB inbuilt  5000 mAh Battery
#
#                                                display  \
# 930  6.5 inches, 720 x 1600 px Display with Water D...
#
#                                          camera  \
# 930  13 MP + 2 MP Dual Rear & 5 MP Front Camera
#
#                                  card           os
# 930  Memory Card Supported, upto 1 TB  Android v10

# %%
df1.loc[930,'processor_name'] = 'Mediatek MT6739'

# %% [markdown]
# **Extracting Processor Brand from Processor Name**

# %%
processor_brand = df1['processor_name'].str.split(' ').str.get(0).str.lower()
df1.insert(11,'processor_brand',processor_brand)

# %% [markdown]
# **Cleaning number of cores column**

# %%
df1['num_cores'] = df1['num_cores'].str.replace('Octa Core Processor','Octa Core').str.replace('Hexa Core Processor','Hexa Core').str.replace('Quad Core Processor','Quad Core')

# %%
df1['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    769
# Quad Core     58
# Hexa Core     47
# Deca Core      1
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning Processor Speed**

# %%
df1['processor_speed'] = df1['processor_speed'].str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)

# %%
df1['processor_speed'].head()
# Out:
# 0    2.2
# 1    2.4
# 2    2.2
# 3    2.2
# 4    2.6
# Name: processor_speed, dtype: float64

# %% [markdown]
# **Extracting Ram and Internal Memory**

# %%
ram_capacity = df1['ram'].str.strip().str.split(',').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)
df1.insert(15,'ram_capacity',ram_capacity)

# %%
internal_memory = df1['ram'].str.strip().str.split(',').str.get(1).str.strip().str.replace('\u2009',' ').str.split(' ').str.get(0)
df1.insert(16,'internal_memory',internal_memory)

# %%
df1['internal_memory'] = df1['internal_memory'].astype(float)

# %%
df1.head()
# Out:
#    index brand_name                                    model  price  rating  \
# 0      2    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3    samsung                    Samsung Galaxy A14 5G  16499    75.0
# 2      4    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5   motorola                     Motorola Moto G62 5G  14999    81.0
# 4      6     realme                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                         processor    processor_name  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor    Snapdragon 695
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor       Exynos 1330
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  Snapdragon  750G
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor   Snapdragon  695
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor    Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                       ram  \
# 0      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 1          exynos  Octa Core              2.4   4 GB RAM, 64 GB inbuilt
# 2      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 3      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6  6 GB RAM, 128 GB inbuilt
#
#    ram_capacity internal_memory                                  battery  \
# 0           6.0             128  5000 mAh Battery with 33W Fast Charging
# 1           4.0              64  5000 mAh Battery with 15W Fast Charging
# 2           6.0             128  5000 mAh Battery with 25W Fast Charging
# 3           6.0             128      5000 mAh Battery with Fast Charging
# 4           6.0             128  5000 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **Cleaning Ram Columns**

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 4.0      265
# 8.0      201
# 6.0      200
# 3.0       94
# 2.0       55
# 12.0      50
# 1.0        4
# 16.0       2
# 64.0       2
# 512.0      1
# 128.0      1
# 256.0      1
# 18.0       1
# 1.5        1
# Name: count, dtype: int64

# %%
df1[df1['ram_capacity'] > 18]
# Out:
#      index brand_name                             model   price  rating  \
# 266    268      apple            Apple iPhone SE 3 2022   43900     NaN
# 313    315     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 420    422      nokia                      Nokia 225 4G    3589     NaN
# 533    535      apple    Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 653    655      apple    Apple iPhone SE 3 2022 (256GB)   58900    61.0
#
#                                                  sim  has_5g  has_nfc  \
# 266          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 313  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 420                          Dual Sim, 3G, 4G, VoLTE   False    False
# 533          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 653          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                         processor  \
# 266           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
# 313            True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 420           False                                       Unisoc T117
# 533           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
# 653           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
#
#          processor_name processor_brand  num_cores  processor_speed  \
# 266         Bionic  A15          bionic  Hexa Core             3.22
# 313  Snapdragon 8+ Gen1      snapdragon  Octa Core             3.20
# 420         Unisoc T117          unisoc        NaN              NaN
# 533         Bionic  A15          bionic  Hexa Core             3.22
# 653         Bionic  A15          bionic  Hexa Core             3.22
#
#                            ram  ram_capacity internal_memory  \
# 266              64 GB inbuilt          64.0             NaN
# 313             512 GB inbuilt         512.0             NaN
# 420  64 MB RAM, 128 MB inbuilt          64.0             128
# 533             128 GB inbuilt         128.0             NaN
# 653             256 GB inbuilt         256.0             NaN
#
#                                      battery  \
# 266                                     None
# 313  4700 mAh Battery with 66W Fast Charging
# 420                         1150 mAh Battery
# 533                                     None
# 653                                     None
#
#                                          display  \
# 266            4.7 inches, 750 x 1334 px Display
# 313  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 420             2.4 inches, 240 x 320 px Display
# 533            4.7 inches, 750 x 1334 px Display
# 653            4.7 inches, 750 x 1334 px Display
#
#                                                 camera  \
# 266                     12 MP Rear & 7 MP Front Camera
# 313  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 420                                 0.3 MP Rear Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 653                     12 MP Rear & 7 MP Front Camera
#
#                                   card                 os
# 266          Memory Card Not Supported            iOS v15
# 313  Memory Card (Hybrid), upto 256 GB   Hongmeng OS v3.0
# 420  Memory Card Supported, upto 32 GB  RTOS (Series 30+)
# 533          Memory Card Not Supported            iOS v15
# 653          Memory Card Not Supported            iOS v15

# %%
df1.loc[[266], ['ram_capacity','internal_memory']]  = [4,'64']
df1.loc[[533], ['ram_capacity','internal_memory']]  = [4,'128']
df1.loc[[653], ['ram_capacity','internal_memory']]  = [4,'256']
df1.loc[[313], ['ram_capacity','internal_memory']]  = [12,'512']

# %%
df1[df1['index'].isin([268,315,422,535,655])]
# Out:
#      index brand_name                             model   price  rating  \
# 266    268      apple            Apple iPhone SE 3 2022   43900     NaN
# 313    315     huawei  Huawei Mate 50 RS Porsche Design  239999    81.0
# 420    422      nokia                      Nokia 225 4G    3589     NaN
# 533    535      apple    Apple iPhone SE 3 2022 (128GB)   48900    61.0
# 653    655      apple    Apple iPhone SE 3 2022 (256GB)   58900    61.0
#
#                                                  sim  has_5g  has_nfc  \
# 266          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 313  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster   False     True
# 420                          Dual Sim, 3G, 4G, VoLTE   False    False
# 533          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 653          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                         processor  \
# 266           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
# 313            True  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 420           False                                       Unisoc T117
# 533           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
# 653           False        Bionic  A15, Hexa Core, 3.22 GHz Processor
#
#          processor_name processor_brand  num_cores  processor_speed  \
# 266         Bionic  A15          bionic  Hexa Core             3.22
# 313  Snapdragon 8+ Gen1      snapdragon  Octa Core             3.20
# 420         Unisoc T117          unisoc        NaN              NaN
# 533         Bionic  A15          bionic  Hexa Core             3.22
# 653         Bionic  A15          bionic  Hexa Core             3.22
#
#                            ram  ram_capacity internal_memory  \
# 266              64 GB inbuilt           4.0              64
# 313             512 GB inbuilt          12.0             512
# 420  64 MB RAM, 128 MB inbuilt          64.0             128
# 533             128 GB inbuilt           4.0             128
# 653             256 GB inbuilt           4.0             256
#
#                                      battery  \
# 266                                     None
# 313  4700 mAh Battery with 66W Fast Charging
# 420                         1150 mAh Battery
# 533                                     None
# 653                                     None
#
#                                          display  \
# 266            4.7 inches, 750 x 1334 px Display
# 313  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 420             2.4 inches, 240 x 320 px Display
# 533            4.7 inches, 750 x 1334 px Display
# 653            4.7 inches, 750 x 1334 px Display
#
#                                                 camera  \
# 266                     12 MP Rear & 7 MP Front Camera
# 313  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 420                                 0.3 MP Rear Camera
# 533                     12 MP Rear & 7 MP Front Camera
# 653                     12 MP Rear & 7 MP Front Camera
#
#                                   card                 os
# 266          Memory Card Not Supported            iOS v15
# 313  Memory Card (Hybrid), upto 256 GB   Hongmeng OS v3.0
# 420  Memory Card Supported, upto 32 GB  RTOS (Series 30+)
# 533          Memory Card Not Supported            iOS v15
# 653          Memory Card Not Supported            iOS v15

# %%
# Dropping Feature Phone
df1.drop([420],inplace=True)

# %%
df1['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 4.0     268
# 8.0     201
# 6.0     200
# 3.0      94
# 2.0      55
# 12.0     51
# 1.0       4
# 16.0      2
# 18.0      1
# 1.5       1
# Name: count, dtype: int64

# %% [markdown]
# **Cleaning Internal Memory Column**

# %%
df1[df1['internal_memory'] == 1]
# Out:
#      index brand_name                                     model   price  \
# 207    209      apple             Apple iPhone 14 Pro Max (1TB)  182999
# 499    501      apple             Apple iPhone 13 Pro Max (1TB)  179900
# 527    529    samsung  Samsung Galaxy Z Fold 4 (12GB RAM + 1TB)  163980
# 559    561      apple                 Apple iPhone 14 Pro (1TB)  172999
# 659    661      apple                 Apple iPhone 13 Pro (1TB)  147900
#
#      rating                                      sim  has_5g  has_nfc  \
# 207    78.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 499    86.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 527     NaN  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 559    77.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
# 659    84.0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True
#
#      has_ir_blaster                                          processor  \
# 207           False                   Bionic  A16, Hexa Core Processor
# 499           False          Bionic A15, Hexa Core, 3.22 GHz Processor
# 527           False  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 559           False                   Bionic  A16, Hexa Core Processor
# 659           False          Bionic A15, Hexa Core, 3.22 GHz Processor
#
#           processor_name processor_brand  num_cores  processor_speed  \
# 207          Bionic  A16          bionic  Hexa Core              NaN
# 499           Bionic A15          bionic  Hexa Core             3.22
# 527  Snapdragon  8+ Gen1      snapdragon  Octa Core             3.20
# 559          Bionic  A16          bionic  Hexa Core              NaN
# 659           Bionic A15          bionic  Hexa Core             3.22
#
#                          ram  ram_capacity  internal_memory  \
# 207   6 GB RAM, 1 TB inbuilt           6.0              1.0
# 499   6 GB RAM, 1 TB inbuilt           6.0              1.0
# 527  12 GB RAM, 1 TB inbuilt          12.0              1.0
# 559   6 GB RAM, 1 TB inbuilt           6.0              1.0
# 659   6 GB RAM, 1 TB inbuilt           6.0              1.0
#
#                                      battery  \
# 207      4323 mAh Battery with Fast Charging
# 499      4352 mAh Battery with Fast Charging
# 527  4400 mAh Battery with 25W Fast Charging
# 559      3200 mAh Battery with Fast Charging
# 659      3095 mAh Battery with Fast Charging
#
#                                                display  \
# 207         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 499  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 527  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 559         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 659  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
#
#                                                 camera  \
# 207  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 499  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 527  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 559  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 659  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card           os
# 207  Memory Card Not Supported      iOS v16
# 499  Memory Card Not Supported      iOS v15
# 527  Memory Card Not Supported  Android v12
# 559  Memory Card Not Supported      iOS v16
# 659  Memory Card Not Supported    iOS v15.0

# %%
temp_df = df1[df1['internal_memory'] == 1]
df1.loc[temp_df.index,'internal_memory'] = 1024

# %%
df1['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0     368
# 64.0      247
# 32.0      122
# 256.0      99
# 512.0      16
# 16.0       16
# 1024.0      5
# 8.0         4
# Name: count, dtype: int64

# %% [markdown]
# **Extracting battery capacity and fast charging**

# %%
battery_capacity = df1['battery'].str.strip().str.split('with').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0).astype(float)
df1.insert(18,'battery_capacity',battery_capacity)

# %%
fast_charging = df1['battery'].str.strip().str.split('with').str.get(1).str.strip().str.findall(r'\d{2,3}')
df1.insert(19,'fast_charging',fast_charging)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 877 entries, 0 to 992
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             877 non-null    int64
#  1   brand_name        877 non-null    object
#  2   model             877 non-null    object
#  3   price             877 non-null    int64
#  4   rating            792 non-null    float64
#  5   sim               877 non-null    object
#  6   has_5g            877 non-null    bool
#  7   has_nfc           877 non-null    bool
#  8   has_ir_blaster    877 non-null    bool
#  9   processor         877 non-null    object
#  10  processor_name    848 non-null    object
#  11  processor_brand   848 non-null    object
#  12  num_cores         875 non-null    object
#  13  processor_speed   862 non-null    float64
#  14  ram               877 non-null    object
#  15  ram_capacity      877 non-null    float64
#  16  internal_memory   877 non-null    float64
#  17  battery           865 non-null    object
#  18  battery_capacity  865 non-null    float64
#  19  fast_charging     638 non-null    object
#  20  display           877 non-null    object
#  21  camera            877 non-null    object
#  22  card              877 non-null    object
#  23  os                872 non-null    object
# dtypes: bool(3), float64(5), int64(2), object(14)
# memory usage: 185.6+ KB

# %%
def fast_charging_extractor(item):

  if type(item) == list:
    if len(item) == 1:
      return item[0]
    else:
      return 0
  else:
    return -1

# %%
df1['fast_charging'] = df1['fast_charging'].apply(fast_charging_extractor).astype(int)

# %%
df1['fast_charging'].value_counts()
# Out:
# fast_charging
# -1      239
#  18     141
#  33     123
#  0       62
#  25      48
#  15      46
#  30      34
#  10      28
#  65      25
#  67      23
#  80      19
#  120     17
#  44      15
#  20      14
#  66      13
#  45       7
#  150      5
#  50       4
#  60       3
#  22       3
#  68       2
#  125      2
#  27       2
#  180      1
#  19       1
# Name: count, dtype: int64

# %% [markdown]
# **Extracting Screen size,Display and Refresh Rate From Display COlumn**

# %%
screen_size = df1['display'].str.strip().str.split(',').str.get(0).str.strip().str.split(' ').str.get(0).astype(float)
df1.insert(21,'screen_size',screen_size)

# %%
resolution = df1['display'].str.strip().str.split(',').str.get(1).str.strip().str.split('px').str.get(0)
df1.insert(22,'resolution',resolution)

# %%
refresh_rate = df1['display'].str.strip().str.split(',').str.get(2).str.strip().str.findall(r'\d{2,3}').str.get(0).apply(lambda x: 60 if pd.isna(x) else x).astype(int)
df1.insert(23,'refresh_rate',refresh_rate)

# %%
df1.head()
# Out:
#    index brand_name                                    model  price  rating  \
# 0      2    oneplus                OnePlus Nord CE 2 Lite 5G  18999    81.0
# 1      3    samsung                    Samsung Galaxy A14 5G  16499    75.0
# 2      4    samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)  16999    80.0
# 3      5   motorola                     Motorola Moto G62 5G  14999    81.0
# 4      6     realme                       Realme 10 Pro Plus  24999    82.0
#
#                                        sim  has_5g  has_nfc  has_ir_blaster  \
# 0       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 1       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC    True     True           False
# 3       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
# 4       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi    True    False           False
#
#                                         processor    processor_name  \
# 0    Snapdragon 695, Octa Core, 2.2 GHz Processor    Snapdragon 695
# 1       Exynos 1330, Octa Core, 2.4 GHz Processor       Exynos 1330
# 2  Snapdragon  750G, Octa Core, 2.2 GHz Processor  Snapdragon  750G
# 3   Snapdragon  695, Octa Core, 2.2 GHz Processor   Snapdragon  695
# 4    Dimensity 1080, Octa Core, 2.6 GHz Processor    Dimensity 1080
#
#   processor_brand  num_cores  processor_speed                       ram  \
# 0      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 1          exynos  Octa Core              2.4   4 GB RAM, 64 GB inbuilt
# 2      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 3      snapdragon  Octa Core              2.2  6 GB RAM, 128 GB inbuilt
# 4       dimensity  Octa Core              2.6  6 GB RAM, 128 GB inbuilt
#
#    ram_capacity  internal_memory                                  battery  \
# 0           6.0            128.0  5000 mAh Battery with 33W Fast Charging
# 1           4.0             64.0  5000 mAh Battery with 15W Fast Charging
# 2           6.0            128.0  5000 mAh Battery with 25W Fast Charging
# 3           6.0            128.0      5000 mAh Battery with Fast Charging
# 4           6.0            128.0  5000 mAh Battery with 67W Fast Charging
#
#    battery_capacity  fast_charging  \
# 0            5000.0             33
# 1            5000.0             15
# 2            5000.0             25
# 3            5000.0              0
# 4            5000.0             67
#
#                                              display  screen_size  \
# 0  6.59 inches, 1080 x 2412 px, 120 Hz Display wi...         6.59
# 1  6.6 inches, 1080 x 2408 px, 90 Hz Display with...         6.60
# 2  6.6 inches, 1080 x 2408 px, 120 Hz Display wit...         6.60
# 3  6.55 inches, 1080 x 2400 px, 120 Hz Display wi...         6.55
# 4  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...         6.70
#
#      resolution  refresh_rate  \
# 0  1080 x 2412            120
# 1  1080 x 2408             90
# 2  1080 x 2408            120
# 3  1080 x 2400            120
# 4  1080 x 2412            120
#
#                                               camera  \
# 0  64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front ...
# 1  50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front ...
# 2  50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front C...
# 3  50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4  108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                card           os
# 0   Memory Card (Hybrid), upto 1 TB  Android v12
# 1  Memory Card Supported, upto 1 TB  Android v13
# 2  Memory Card Supported, upto 1 TB  Android v12
# 3   Memory Card (Hybrid), upto 1 TB  Android v12
# 4         Memory Card Not Supported  Android v13

# %% [markdown]
# **Extracting Number of Camers**

# %%
df1['camera'].value_counts()
# Out:
# camera
# 8 MP Rear & 5 MP Front Camera                                         30
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            29
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  29
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  28
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  27
# 13 MP Rear & 5 MP Front Camera                                        26
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                            25
# 48 MP Quad Rear & 16 MP Front Camera                                  21
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                          20
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   18
# 13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   17
# 13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                   17
# 48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  17
# 64 MP Quad Rear & 16 MP Front Camera                                  17
# 64 MP Quad Rear & 32 MP Front Camera                                  15
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                            14
# 48 MP Quad Rear & 8 MP Front Camera                                   14
# 12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                14
# 50 MP Quad Rear & 8 MP Front Camera                                   13
# 108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                 13
# 48 MP Quad Rear & 13 MP Front Camera                                  12
# 48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   10
# 50 MP + 2 MP Dual Rear & 5 MP Front Camera                            10
# 8 MP Dual Rear & 5 MP Front Camera                                     9
# 64 MP Quad Rear & 20 MP Front Camera                                   9
# 13 MP Dual Rear & 8 MP Front Camera                                    9
# 64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   9
# 20 MP Rear & 13 MP Front Camera                                        9
# 48 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                 8
# 13 MP Quad Rear & 8 MP Front Camera                                    7
# 50 MP + 2 MP Triple Rear & 16 MP Front Camera                          7
# 108 MP Quad Rear & 16 MP Front Camera                                  7
# 12 MP Rear & 7 MP Front Camera                                         7
# 64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   7
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                            6
# 50 MP Dual Rear & 8 MP Front Camera                                    6
# 64 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                 6
# 50 MP + 2 MP Triple Rear & 8 MP Front Camera                           6
# 13 MP Rear & 8 MP Front Camera                                         6
# 48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   5
# 48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                  5
# 64 MP Quad Rear & 13 MP Front Camera                                   5
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   5
# 8 MP + 0.3 MP Dual Rear & 5 MP Front Camera                            5
# 50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    5
# 13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   5
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP Front Camera                 4
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                           4
# 5 MP Rear & 5 MP Front Camera                                          4
# 48 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                   4
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                   4
# 64 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                       4
# 16 MP Rear & 13 MP Front Camera                                        4
# 12.2 MP Rear & 8 MP Front Camera                                       4
# 50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                  4
# 108 MP Quad Rear & 32 MP Front Camera                                  4
# 12 MP Quad Rear & 8 MP Front Camera                                    4
# 12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front Camera                  4
# 12 MP Rear & 5 MP Front Camera                                         3
# 48 MP Quad Rear & 32 MP Front Camera                                   3
# 5 MP Rear & 2 MP Front Camera                                          3
# 50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front Camera                   3
# 64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                   3
# 48 MP + 13 MP + 13 MP Triple Rear & 16 MP Front Camera                 3
# 13 MP Rear & 13 MP Front Camera                                        3
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                   3
# 108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                  3
# 64 MP + 13 MP + 5 MP Triple Rear & 24 MP Front Camera                  3
# 12 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    3
# 16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   3
# 48 MP Triple Rear & 8 MP Front Camera                                  3
# 8 MP + 0.08 MP Dual Rear & 5 MP Front Camera                           3
# 50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                   3
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     3
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera                            3
# 13 MP + 2 MP Dual Rear & 13 MP Front Camera                            3
# 50 MP + 50 MP Dual Rear & 16 MP Front Camera                           3
# 50 MP Quad Rear & 13 MP Front Camera                                   3
# 108 MP Quad Rear & 40 MP Front Camera                                  3
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     2
# 50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front Camera                  2
# 16 MP + 2 MP Dual Rear & 8 MP Front Camera                             2
# 50 MP + 0.3 MP Dual Rear & 5 MP Front Camera                           2
# 12 MP + 2 MP Dual Rear & 8 MP Front Camera                             2
# 13 MP + 5 MP Dual Rear & 8 MP Front Camera                             2
# 64 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                  2
# 12 MP + 2 MP Dual Rear & 5 MP Front Camera                             2
# 50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Front Camera               2
# 50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front Camera                  2
# 48 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                       2
# 108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                  2
# 64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                   2
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                   2
# 64 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 12 MP + 12 MP Dual Rear & 8 MP Front Camera                            2
# 48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                   2
# 25 MP + 8 MP + 5 MP Triple Rear & 25 MP Front Camera                   2
# 13 MP + 2 MP Triple Rear & 8 MP Front Camera                           2
# 108 MP + 2 MP Dual Rear & 16 MP Front Camera                           2
# 64 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   2
# 108 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                  2
# 200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  2
# 50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 64 MP Quad Rear & 20 MP + 2 MP Dual Front Camera                       2
# 12 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                    2
# 13 MP + 2 MP Dual Rear & 16 MP Front Camera                            2
# 50 MP + 50 MP + 16 MP Triple Rear & 16 MP Front Camera                 2
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera       2
# 12 MP + 2 MP Dual Rear & 13 MP Front Camera                            2
# 48 MP Quad Rear & 20 MP Front Camera                                   2
# 48 MP + 2 MP Dual Rear & 5 MP Front Camera                             2
# 50 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                 2
# 108 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera      2
# 64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                   2
# 50 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                 2
# 200 MP + 50 MP + 12 MP Triple Rear & 60 MP Front Camera                2
# 16 MP Rear & 16 MP Front Camera                                        2
# 48 MP + 5 MP Dual Rear & 16 MP Front Camera                            2
# 50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                    2
# 50 MP + Depth Sensor Dual Rear & 8 MP Front Camera                     2
# 16 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 50 MP + 13 MP + 12 MP Triple Rear & 16 MP Front Camera                 2
# 50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                   2
# 12 MP + 5 MP Dual Rear & 20 MP Front Camera                            2
# 8 MP Rear & 2 MP Front Camera                                          1
# 16 MP Rear & 8 MP Front Camera                                         1
# 48 MP + 5 MP Dual Rear & 13 MP Front Camera                            1
# 48 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   1
# 13 MP Rear & 16 MP Front Camera                                        1
# 20 MP + 12 MP Dual Rear & 20 MP Front Camera                           1
# 16 MP + 5 MP Dual Rear & 16 MP Front Camera                            1
# 16 MP + 13 MP + 13 MP Triple Rear & 8 MP Front Camera                  1
# 64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                   1
# 13 MP + 0.3 MP Dual Rear & 8 MP Front Camera                           1
# 13 MP Quad Rear & 16 MP Front Camera                                   1
# 8 MP Dual Rear & 8 MP Front Camera                                     1
# 12.3 MP Rear & 8 MP Front Camera                                       1
# 5 MP Rear Camera                                                       1
# 16 MP Quad Rear & 16 MP Front Camera                                   1
# 50 MP Triple Rear & 8 MP Front Camera                                  1
# 64 MP Quad Rear & 44 MP + 2 MP Dual Front Camera                       1
# 13 MP + 2 MP Dual Rear & 13 MP + 2 MP Dual Front Camera                1
# 12 MP + 12 MP Dual Rear & 5 MP Front Camera                            1
# 13 MP Rear & 20 MP Front Camera                                        1
# 16 MP Rear & 24 MP Front Camera                                        1
# 16 MP + 5 MP Dual Rear & 24 MP Front Camera                            1
# 16 MP + 2 MP Dual Rear & 16 MP Front Camera                            1
# 64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 12 MP + 5 MP Dual Rear & 16 MP Front Camera                            1
# 16 MP + 2 MP Dual Rear & 25 MP Front Camera                            1
# 16 MP + 12 MP + 5 MP Triple Rear & 12 MP Front Camera                  1
# 32 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 16 MP Dual Rear & 8 MP Front Camera                                    1
# 48 MP Quad Rear & 16 MP + 8 MP Dual Front Camera                       1
# 13 MP Dual Rear & 5 MP Front Camera                                    1
# 13 MP Rear & 2 MP Front Camera                                         1
# 12 MP Quad Rear & 16 MP Front Camera                                   1
# 13 MP Rear Camera                                                      1
# 13 MP + Depth Sensor Triple Rear & 8 MP Front Camera                   1
# 12 MP Quad Rear & 12 MP Front Camera                                   1
# 12.2 MP Rear & 8 MP + 8 MP Dual Front Camera                           1
# 200 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                 1
# 50 MP Quad Rear & 32 MP Front Camera                                   1
# 64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 50 MP Quad Rear & 16 MP Front Camera                                   1
# 16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual Front Camera            1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP + 8 MP Dual Front Camera     1
# 50 MP + 12 MP Dual Rear & 8 MP Front Camera                            1
# 108 MP + 2 MP Triple Rear & 16 MP Front Camera                         1
# 50 MP + 12 MP Dual Rear & 10.8 MP Front Camera                         1
# 108 MP + 13 MP + 2 MP Triple Rear & 60 MP Front Camera                 1
# 20 MP + 16 MP Dual Rear & 16 MP Front Camera                           1
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 48 MP + 12 MP Triple Rear & 10.8 MP Front Camera               1
# 50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 50 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front Camera                  1
# 50 MP + 50 MP + 2 MP Triple Rear & 60 MP Front Camera                  1
# 64 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 12.2 MP + 12 MP Dual Rear & 8 MP Front Camera                          1
# 48 MP + 2 MP Dual Rear & 8 MP Front Camera                             1
# 50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 MP Dual Front Camera      1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 3 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 13 MP + 2 MP Dual Rear & 20 MP Front Camera                            1
# 2 MP Rear Camera                                                       1
# 13 MP + 5 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 25 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 108 MP Quad Rear & 20 MP Front Camera                                  1
# 64 MP Quad Rear & 48 MP Front Camera                                   1
# 48 MP + 2 MP Triple Rear & 32 MP Front Camera                          1
# 64 MP Quad Rear & 16 MP + 8 MP Dual Front Camera                       1
# 108 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                 1
# 24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front Camera                   1
# 64 MP Quad Rear & 10 MP Front Camera                                   1
# 48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 12 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 48 MP Quad Rear & 16 MP + 2 MP Dual Front Camera                       1
# 64 MP + 2 MP Triple Rear & 16 MP Front Camera                          1
# 13 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera                      1
# 13 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   1
# 108 MP + 16 MP + 8 MP Triple Rear & 25 MP Front Camera                 1
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP + 8 MP Dual Front Camera       1
# 16 MP + 12.2 MP Dual Rear & 8 MP Front Camera                          1
# 16 MP Rear & 5 MP Front Camera                                         1
# Name: count, dtype: int64

# %%
def camera_extractor(text):

  if 'Quad' in text:
    return '4'
  elif 'Triple' in text:
    return '3'
  elif 'Dual' in text:
    return '2'
  elif 'Missing' in text:
    return 'Missing'
  else:
    return '1'

# %%
num_rear_cameras = df1['camera'].str.strip().str.split('&').str.get(0).apply(camera_extractor)
df1.insert(25,'num_rear_cameras',num_rear_cameras)

# %%
num_front_cameras = df1['camera'].str.strip().str.split('&').str.get(1).str.strip().fillna('Missing').apply(camera_extractor)
df1.insert(26,'num_front_cameras',num_front_cameras)

# %%
df1[df1['num_front_cameras'] == 'Missing']
# Out:
#      index brand_name      model  price  rating  \
# 606    608       itel  itel A23s   4699     NaN
# 925    927        cat    CAT S42  21999    62.0
# 976    978      ikall   iKall K2   3989     NaN
#
#                                 sim  has_5g  has_nfc  has_ir_blaster  \
# 606         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 925         Dual Sim, 3G, 4G, Wi-Fi   False    False           False
# 976  Dual Sim, 3G, 4G, VoLTE, Wi-Fi   False    False           False
#
#                                              processor       processor_name  \
# 606  Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor  Spreadtrum  SC9832E
# 925            Helio A20, Deca Core, 1.8 GHz Processor            Helio A20
# 976                                Quad Core Processor                 None
#
#     processor_brand  num_cores  processor_speed                      ram  \
# 606      spreadtrum  Quad Core              1.4  2 GB RAM, 32 GB inbuilt
# 925           helio  Deca Core              1.8  3 GB RAM, 32 GB inbuilt
# 976            None  Quad Core              NaN   1 GB RAM, 8 GB inbuilt
#
#      ram_capacity  internal_memory           battery  battery_capacity  \
# 606           2.0             32.0  3020 mAh Battery            3020.0
# 925           3.0             32.0  4200 mAh Battery            4200.0
# 976           1.0              8.0  2200 mAh Battery            2200.0
#
#      fast_charging                            display  screen_size  \
# 606             -1     5 inches, 854 x 480 px Display          5.0
# 925             -1  5.5 inches, 1440 x 720 px Display          5.5
# 976             -1     5 inches, 854 x 480 px Display          5.0
#
#       resolution  refresh_rate             camera num_rear_cameras  \
# 606   854 x 480             60   2 MP Rear Camera                1
# 925  1440 x 720             60  13 MP Rear Camera                1
# 976   854 x 480             60   5 MP Rear Camera                1
#
#     num_front_cameras                               card  \
# 606           Missing          Memory Card Not Supported
# 925           Missing  Memory Card (Hybrid), upto 128 GB
# 976           Missing          Memory Card Not Supported
#
#                              os
# 606                 Android v11
# 925                 Android v10
# 976  Android v6.0 (Marshmallow)

# %% [markdown]
# **Extracting Pixels of Front and Rear Camera**

# %%
df1['camera'].value_counts()
# Out:
# camera
# 8 MP Rear & 5 MP Front Camera                                         30
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                            29
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  29
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  28
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  27
# 13 MP Rear & 5 MP Front Camera                                        26
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                            25
# 48 MP Quad Rear & 16 MP Front Camera                                  21
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                          20
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   18
# 13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   17
# 13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                   17
# 48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  17
# 64 MP Quad Rear & 16 MP Front Camera                                  17
# 64 MP Quad Rear & 32 MP Front Camera                                  15
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                            14
# 48 MP Quad Rear & 8 MP Front Camera                                   14
# 12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                14
# 50 MP Quad Rear & 8 MP Front Camera                                   13
# 108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                 13
# 48 MP Quad Rear & 13 MP Front Camera                                  12
# 48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                   10
# 50 MP + 2 MP Dual Rear & 5 MP Front Camera                            10
# 8 MP Dual Rear & 5 MP Front Camera                                     9
# 64 MP Quad Rear & 20 MP Front Camera                                   9
# 13 MP Dual Rear & 8 MP Front Camera                                    9
# 64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   9
# 20 MP Rear & 13 MP Front Camera                                        9
# 48 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                 8
# 13 MP Quad Rear & 8 MP Front Camera                                    7
# 50 MP + 2 MP Triple Rear & 16 MP Front Camera                          7
# 108 MP Quad Rear & 16 MP Front Camera                                  7
# 12 MP Rear & 7 MP Front Camera                                         7
# 64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   7
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                            6
# 50 MP Dual Rear & 8 MP Front Camera                                    6
# 64 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                 6
# 50 MP + 2 MP Triple Rear & 8 MP Front Camera                           6
# 13 MP Rear & 8 MP Front Camera                                         6
# 48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   5
# 48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                  5
# 64 MP Quad Rear & 13 MP Front Camera                                   5
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   5
# 8 MP + 0.3 MP Dual Rear & 5 MP Front Camera                            5
# 50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    5
# 13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                   5
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP Front Camera                 4
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                           4
# 5 MP Rear & 5 MP Front Camera                                          4
# 48 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                   4
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                   4
# 64 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                       4
# 16 MP Rear & 13 MP Front Camera                                        4
# 12.2 MP Rear & 8 MP Front Camera                                       4
# 50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                  4
# 108 MP Quad Rear & 32 MP Front Camera                                  4
# 12 MP Quad Rear & 8 MP Front Camera                                    4
# 12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front Camera                  4
# 12 MP Rear & 5 MP Front Camera                                         3
# 48 MP Quad Rear & 32 MP Front Camera                                   3
# 5 MP Rear & 2 MP Front Camera                                          3
# 50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front Camera                   3
# 64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                   3
# 48 MP + 13 MP + 13 MP Triple Rear & 16 MP Front Camera                 3
# 13 MP Rear & 13 MP Front Camera                                        3
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                   3
# 108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                  3
# 64 MP + 13 MP + 5 MP Triple Rear & 24 MP Front Camera                  3
# 12 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    3
# 16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   3
# 48 MP Triple Rear & 8 MP Front Camera                                  3
# 8 MP + 0.08 MP Dual Rear & 5 MP Front Camera                           3
# 50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                   3
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     3
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera                            3
# 13 MP + 2 MP Dual Rear & 13 MP Front Camera                            3
# 50 MP + 50 MP Dual Rear & 16 MP Front Camera                           3
# 50 MP Quad Rear & 13 MP Front Camera                                   3
# 108 MP Quad Rear & 40 MP Front Camera                                  3
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera     2
# 50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front Camera                  2
# 16 MP + 2 MP Dual Rear & 8 MP Front Camera                             2
# 50 MP + 0.3 MP Dual Rear & 5 MP Front Camera                           2
# 12 MP + 2 MP Dual Rear & 8 MP Front Camera                             2
# 13 MP + 5 MP Dual Rear & 8 MP Front Camera                             2
# 64 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                  2
# 12 MP + 2 MP Dual Rear & 5 MP Front Camera                             2
# 50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Front Camera               2
# 50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front Camera                  2
# 48 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                       2
# 108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                  2
# 64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                   2
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                   2
# 64 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 12 MP + 12 MP Dual Rear & 8 MP Front Camera                            2
# 48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                   2
# 25 MP + 8 MP + 5 MP Triple Rear & 25 MP Front Camera                   2
# 13 MP + 2 MP Triple Rear & 8 MP Front Camera                           2
# 108 MP + 2 MP Dual Rear & 16 MP Front Camera                           2
# 64 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   2
# 108 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                  2
# 200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                  2
# 50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 64 MP Quad Rear & 20 MP + 2 MP Dual Front Camera                       2
# 12 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                    2
# 13 MP + 2 MP Dual Rear & 16 MP Front Camera                            2
# 50 MP + 50 MP + 16 MP Triple Rear & 16 MP Front Camera                 2
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera       2
# 12 MP + 2 MP Dual Rear & 13 MP Front Camera                            2
# 48 MP Quad Rear & 20 MP Front Camera                                   2
# 48 MP + 2 MP Dual Rear & 5 MP Front Camera                             2
# 50 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                 2
# 108 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera      2
# 64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                   2
# 50 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                 2
# 200 MP + 50 MP + 12 MP Triple Rear & 60 MP Front Camera                2
# 16 MP Rear & 16 MP Front Camera                                        2
# 48 MP + 5 MP Dual Rear & 16 MP Front Camera                            2
# 50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                    2
# 50 MP + Depth Sensor Dual Rear & 8 MP Front Camera                     2
# 16 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                    2
# 50 MP + 13 MP + 12 MP Triple Rear & 16 MP Front Camera                 2
# 50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                   2
# 12 MP + 5 MP Dual Rear & 20 MP Front Camera                            2
# 8 MP Rear & 2 MP Front Camera                                          1
# 16 MP Rear & 8 MP Front Camera                                         1
# 48 MP + 5 MP Dual Rear & 13 MP Front Camera                            1
# 48 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                   1
# 13 MP Rear & 16 MP Front Camera                                        1
# 20 MP + 12 MP Dual Rear & 20 MP Front Camera                           1
# 16 MP + 5 MP Dual Rear & 16 MP Front Camera                            1
# 16 MP + 13 MP + 13 MP Triple Rear & 8 MP Front Camera                  1
# 64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                   1
# 13 MP + 0.3 MP Dual Rear & 8 MP Front Camera                           1
# 13 MP Quad Rear & 16 MP Front Camera                                   1
# 8 MP Dual Rear & 8 MP Front Camera                                     1
# 12.3 MP Rear & 8 MP Front Camera                                       1
# 5 MP Rear Camera                                                       1
# 16 MP Quad Rear & 16 MP Front Camera                                   1
# 50 MP Triple Rear & 8 MP Front Camera                                  1
# 64 MP Quad Rear & 44 MP + 2 MP Dual Front Camera                       1
# 13 MP + 2 MP Dual Rear & 13 MP + 2 MP Dual Front Camera                1
# 12 MP + 12 MP Dual Rear & 5 MP Front Camera                            1
# 13 MP Rear & 20 MP Front Camera                                        1
# 16 MP Rear & 24 MP Front Camera                                        1
# 16 MP + 5 MP Dual Rear & 24 MP Front Camera                            1
# 16 MP + 2 MP Dual Rear & 16 MP Front Camera                            1
# 64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 12 MP + 5 MP Dual Rear & 16 MP Front Camera                            1
# 16 MP + 2 MP Dual Rear & 25 MP Front Camera                            1
# 16 MP + 12 MP + 5 MP Triple Rear & 12 MP Front Camera                  1
# 32 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 16 MP Dual Rear & 8 MP Front Camera                                    1
# 48 MP Quad Rear & 16 MP + 8 MP Dual Front Camera                       1
# 13 MP Dual Rear & 5 MP Front Camera                                    1
# 13 MP Rear & 2 MP Front Camera                                         1
# 12 MP Quad Rear & 16 MP Front Camera                                   1
# 13 MP Rear Camera                                                      1
# 13 MP + Depth Sensor Triple Rear & 8 MP Front Camera                   1
# 12 MP Quad Rear & 12 MP Front Camera                                   1
# 12.2 MP Rear & 8 MP + 8 MP Dual Front Camera                           1
# 200 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                 1
# 50 MP Quad Rear & 32 MP Front Camera                                   1
# 64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 50 MP Quad Rear & 16 MP Front Camera                                   1
# 16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual Front Camera            1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP + 8 MP Dual Front Camera     1
# 50 MP + 12 MP Dual Rear & 8 MP Front Camera                            1
# 108 MP + 2 MP Triple Rear & 16 MP Front Camera                         1
# 50 MP + 12 MP Dual Rear & 10.8 MP Front Camera                         1
# 108 MP + 13 MP + 2 MP Triple Rear & 60 MP Front Camera                 1
# 20 MP + 16 MP Dual Rear & 16 MP Front Camera                           1
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 48 MP + 12 MP Triple Rear & 10.8 MP Front Camera               1
# 50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 50 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front Camera                  1
# 50 MP + 50 MP + 2 MP Triple Rear & 60 MP Front Camera                  1
# 64 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                  1
# 108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                  1
# 12.2 MP + 12 MP Dual Rear & 8 MP Front Camera                          1
# 48 MP + 2 MP Dual Rear & 8 MP Front Camera                             1
# 50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 MP Dual Front Camera      1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 50 MP + 3 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 13 MP + 2 MP Dual Rear & 20 MP Front Camera                            1
# 2 MP Rear Camera                                                       1
# 13 MP + 5 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 25 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                   1
# 108 MP Quad Rear & 20 MP Front Camera                                  1
# 64 MP Quad Rear & 48 MP Front Camera                                   1
# 48 MP + 2 MP Triple Rear & 32 MP Front Camera                          1
# 64 MP Quad Rear & 16 MP + 8 MP Dual Front Camera                       1
# 108 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                 1
# 24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front Camera                   1
# 64 MP Quad Rear & 10 MP Front Camera                                   1
# 48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 12 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                 1
# 48 MP Quad Rear & 16 MP + 2 MP Dual Front Camera                       1
# 64 MP + 2 MP Triple Rear & 16 MP Front Camera                          1
# 13 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                    1
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera                      1
# 13 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                   1
# 108 MP + 16 MP + 8 MP Triple Rear & 25 MP Front Camera                 1
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP + 8 MP Dual Front Camera       1
# 16 MP + 12.2 MP Dual Rear & 8 MP Front Camera                          1
# 16 MP Rear & 5 MP Front Camera                                         1
# Name: count, dtype: int64

# %%
df1['primary_camera_rear'] = df1['camera'].str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)
df1['primary_camera_front'] = df1['camera'].str.split('&').str.get(1).str.strip().str.split(' ').str.get(0).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 877 entries, 0 to 992
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 877 non-null    int64
#  1   brand_name            877 non-null    object
#  2   model                 877 non-null    object
#  3   price                 877 non-null    int64
#  4   rating                792 non-null    float64
#  5   sim                   877 non-null    object
#  6   has_5g                877 non-null    bool
#  7   has_nfc               877 non-null    bool
#  8   has_ir_blaster        877 non-null    bool
#  9   processor             877 non-null    object
#  10  processor_name        848 non-null    object
#  11  processor_brand       848 non-null    object
#  12  num_cores             875 non-null    object
#  13  processor_speed       862 non-null    float64
#  14  ram                   877 non-null    object
#  15  ram_capacity          877 non-null    float64
#  16  internal_memory       877 non-null    float64
#  17  battery               865 non-null    object
#  18  battery_capacity      865 non-null    float64
#  19  fast_charging         877 non-null    int64
#  20  display               877 non-null    object
#  21  screen_size           877 non-null    float64
#  22  resolution            877 non-null    object
#  23  refresh_rate          877 non-null    int64
#  24  camera                877 non-null    object
#  25  num_rear_cameras      877 non-null    object
#  26  num_front_cameras     877 non-null    object
#  27  card                  877 non-null    object
#  28  os                    872 non-null    object
#  29  primary_camera_rear   877 non-null    object
#  30  primary_camera_front  874 non-null    object
# dtypes: bool(3), float64(6), int64(4), object(18)
# memory usage: 233.6+ KB

# %%
df1['card'].value_counts()
# Out:
# card
# Memory Card Not Supported             213
# Memory Card Supported, upto 256 GB    162
# Memory Card Supported, upto 1 TB      147
# Memory Card Supported, upto 512 GB    124
# Memory Card (Hybrid), upto 1 TB        68
# Memory Card Supported                  55
# Memory Card (Hybrid)                   22
# Memory Card Supported, upto 128 GB     21
# Memory Card (Hybrid), upto 256 GB      16
# Memory Card (Hybrid), upto 512 GB      15
# Memory Card (Hybrid), upto 128 GB      11
# Memory Card Supported, upto 2 TB        9
# Memory Card (Hybrid), upto 64 GB        6
# Memory Card Supported, upto 64 GB       4
# Memory Card Supported, upto 32 GB       3
# Memory Card (Hybrid), upto 400 GB       1
# Name: count, dtype: int64

# %%
df1['extended_memory'] = df1['card'].apply(lambda x:'0' if 'Not' in x else x.split('upto')).str.get(-1).str.strip().str.replace('Memory Card Supported','Not Specified')

# %%
df1['os'].value_counts()
# Out:
# os
# Android v11                     277
# Android v12                     248
# Android v10                     119
# Android v9.0 (Pie)               52
# Android v10.0                    37
# Android v8.1 (Oreo)              27
# iOS v16                          14
# iOS v15                          13
# Android v13                      12
# Android v8.0 (Oreo)              11
# iOS v13                           7
# Android v6.0 (Marshmallow)        7
# Android v5.1 (Lollipop)           6
# iOS v14                           6
# Android v11.0                     5
# Android v9 (Pie)                  4
# iOS v15.0                         4
# iOS v14.0                         3
# Android v6.0.1 (Marshmallow)      3
# Android v7.0 (Nougat)             2
# Android v5.1.1 (Lollipop)         2
# Android                           2
# Android v7.1.2 (Nougat)           2
# Android v7.1 (Nougat)             2
# Hongmeng OS v3.0                  1
# iOS v10.0.1                       1
# Blackberry OS v10.3               1
# Android v11.1                     1
# Android v9.1 (Pie)                1
# Android v7.1.1 (Nougat)           1
# Android v4.4.2 (KitKat)           1
# Name: count, dtype: int64

# %%
def os_extractor(text):

  if 'Android' in text:
    return 'android'
  elif 'iOS' in text:
    return 'ios'
  elif 'Blackberry' in text or 'Hongmeng' in text:
    return 'other'
  elif text == 'Not Specified':
    return text

# %%
df1['os'].isnull().sum()
# Out:
# 5

# %%
df1['os'].fillna('Not Specified', inplace = True)
# Out:
# <ipython-input-121-08f59eb63c4c>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['os'].fillna('Not Specified', inplace = True)

# %%
df1['os'] = df1['os'].apply(os_extractor)

# %%
df1['os'].value_counts()
# Out:
# os
# android          822
# ios               48
# Not Specified      5
# other              2
# Name: count, dtype: int64

# %%
export_df = df1.drop(columns=['index','sim','processor','ram','battery','display','camera','card'])
export_df.to_csv('smartphone_cleaned_my.csv',index=False)
